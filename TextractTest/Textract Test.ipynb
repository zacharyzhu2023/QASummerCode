# %%
import boto3
from collections import Counter
import re
import datetime as dt

# %%
# Start up a client instance for textract
client = boto3.client('textract')
# All the sample pathways to test SN generation
paths = ['catalina-4-19-21.jpg', 'catalina-10-5-21.jpg', 'indoor-5-17-21.jpg', 'mini-3-5-2021.jpg',
         'mini-4-22-20.jpg', 'mini-5-31-21.jpg', 'mini-10-5-21.jpg', 'mini-12-21-20.jpg', 'mini-26-4-21.jpg']

# %%
# Function to extract text from an image
def analyzeDocument(path):
    with open(path, 'rb') as raw_image: # Open the image from path
        tempImage = raw_image.read() # Read in the image
        byteImage = bytearray(tempImage) # Convert to a byte array
    response = client.detect_document_text(Document = {'Bytes': byteImage}) # Call text detection method
    return response

# %%
# Keep only the tabular data
'''
Intuition for the filter
- We know that the SN has to be of a sufficient length (with some buffer in case some characters are filtered out)
- Some queries will include excessive spaces (we know that in theory the SN should be one big blob)
    - Can remove any queries that don't have any digits or alphabetical characters since SN should contain both
'''

# Helper method to make the batch number based off of the text info
def getBatchNumber(tableData):
    formattedDate = '' # Get the formatted date to create the batch number
    lineVal = '' # Get the line value from the textract text blob
    try:
        dateVal = tableData[tableData.index('Date:')+1]
        if '/' in dateVal:
            try:
                formattedDate = dt.datetime.strptime(dateVal, '%m/%d/%Y').strftime('%Y%m%d')
            except Exception as e:
                print('error with date formatting:', e)
        elif '-' in dateVal:
            try:
                formattedDate = dt.datetime.strptime(dateVal, '%Y-%m-%d').strftime('%Y%m%d')
            except Exception as e:
                print('error with date formatting:', e)
        else:
            formattedDate = ''
    except Exception as e:
        pass
        
    try:
        lineVal = tableData[tableData.index('Line:')+1]
    except Exception as e:
        pass
    batchNumber = 'NA' + formattedDate + '-' + lineVal
    return batchNumber

# Helper method to get the device type
def getDeviceType(tableData):
    for s in tableData:
        if 'Blink' in s:
            return s
    return 'Device type not found'

# Helper method to find the "majority" ruling
def mostCommonElement(lst):
    temp = Counter(lst).most_common(1) # Get the most frequent element + its count
    return temp[0][0] # Return the most frequently appearing element

# Entries that are deemed suspicious
def flagEntries(lst):
    prefixes = [s[:7] for s in lst] # Get the first 7 characters
    lengths = [len(s) for s in lst] # Get the length of the sequence
    isDuplicate = [lst.count(s) > 1 for s in lst] # Check to see if they're are duplicates
    allowedChars = set('ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789-') # Only possible characters in SN
    containsIrreg = [bool(re.search('[^A-za-z0-9-]', s)) for s in lst] # Look for suspicious characters
    mcp = mostCommonElement(prefixes) # Get most common prefix
    mcl = mostCommonElement(lengths) # Get most commonly appearing length
    suspicious = [prefixes[i] != mcp or lengths[i] != mcl or isDuplicate[i] or containsIrreg[i] for i in range(len(lst))] # Corresponds to suspicious entries
    return suspicious

def testRelevant():
    allFormatted = []
    cleaned = []
    allText = []
    batchNumbers = []
    deviceType = []
    for path in paths: # Iterate across all paths
        results = analyzeDocument(path) # Analyze the given image
        blocks = results['Blocks'] # Extract only relevant information
        tableData = [x['Text'] for x in blocks if x['BlockType'] == 'LINE'] # Only keep data that is a "line"
        cleanedData = [] # Use a list b/c algorithm can produce duplicates
        for t in tableData:
            if len(t) > 8 and any(c.isdigit() for c in t) and any(c.isalpha() for c in t) and 'Date' not in t and t.count(' ') <= 2:
                cleanedData.append(t) # Only include non-filtered out data
        batchNumber = getBatchNumber(tableData)
        deviceType = getDeviceType(tableData)
        suspicion = flagEntries(cleanedData)
        #return (allText, cleaned)
        formattedDict = {
            'SerialNumbers': cleanedData,
            'All Text': tableData,
            'Suspicion': suspicion,
            'Batch Number': batchNumber,
            'Device Type': deviceType
        }
        allFormatted.append(formattedDict)
    return allFormatted

allDicts = testRelevant()
for d in allDicts:
    for key in d:
        print(key + ':', d[key], '\n')
    print('\n\n\n')
# print(serialNums[0]) # Sanity Check
# Out:
# SerialNumbers: ['G8T1JX00114208BW', 'G8T1JX00114208C4', '8T1JX00114208C5', 'G8T1JX00114208C2', 'G8T1JX00114209JA', 'G8T1JX00114208BF', 'G8T1JX00114208BH', 'G8T1JX00114208BR', 'G8T1JX00114208C6', 'G8T1JX00114208BV', 'G8T1JX00114208BT', 'G8T1JX00114208BD']
#
# All Text: ['OR', 'Date:', '4/19/2021', 'Line:', 'A17', 'Shift:', 'Day', 'Blink Catalina Camera US', 'No', 'SN', 'No', 'SN', '1', 'G8T1JX00114208BW', '7', 'G8T1JX00114208C4', '2', '8T1JX00114208C5', '8', 'G8T1JX00114208C2', '3', 'G8T1JX00114209JA', '9', 'G8T1JX00114208BF', '4', 'G8T1JX00114208BH', '10', 'G8T1JX00114208BR', '5', 'G8T1JX00114208C6', '11', 'G8T1JX00114208BV', '6', 'G8T1JX00114208BT', '12', 'G8T1JX00114208BD']
#
# Suspicion: [False, False, True, False, False, False, False, False, False, False, False, False]
#
# Batch Number: NA20210419-A17
#
# Device Type: Blink Catalina Camera US
#
#
#
#
#
# SerialNumbers: ['G8V1GH001095MP09', 'G8V1GH001095MPOA', 'G8V1GH001095MPOR', 'G8V1GH001095MNXU', 'G8V1GH001095MP04', 'G8V1GH001095MPOE', 'G8V1GH001095MP07', 'G8V1GH001095MPOB', 'G8V1GH001095MP08', 'G8V1GH001095MNXX', 'G8V1GH001095MP05', 'G8V1GH001095MNXT']
#
# All Text: ['Date:', '10/5/2021', 'Line:', '3', 'Shift:', 'Day', 'Blink Catalina', 'No', 'SN', 'No', 'SN', 'No', 'SN', 'x', 'G8V1GH001095MP09', 'x', 'G8V1GH001095MPOA', 'x', 'G8V1GH001095MPOR', 'G8V1GH001095MNXU', 'G8V1GH001095MP04', 'x', 'G8V1GH001095MPOE', 'G8V1GH001095MP07', 'G8V1GH001095MPOB', 'x', 'G8V1GH001095MP08', 't', 'G8V1GH001095MNXX', '&', 'G8V1GH001095MP05', 'y', 'G8V1GH001095MNXT']
#
# Suspicion: [False, False, False, False, False, False, False, False, False, False, False, False]
#
# Batch Number: NA20211005-3
#
# Device Type: Blink Catalina
#
#
#
#
#
# SerialNumbers: ['G8T1JX0011733TTO', 'G8T1JX0011733TSM', 'G8T1JX0011733TSK', 'G8T1JX0011733TSX', 'G8T1JX0011733TSQ', 'G8T1JX0011733TT2', 'G8T1JX0011733TSP', 'G8T1JX0011733TSN', 'G8T1JX0011733TSR', 'G8T1JX0011733TST', 'G8T1JX0011733TSS', 'G8T1JX0011733TSU']
#
# All Text: ['1', 'Date: 2021-05-17 Line: A9 Shift:', 'Day', 'NA Indoor Camcra', 'No', 'SN', 'No', 'SN', '1', 'G8T1JX0011733TTO', '7', 'G8T1JX0011733TSM', '2', 'G8T1JX0011733TSK', '8', 'G8T1JX0011733TSX', '3', 'G8T1JX0011733TSQ', '9', 'G8T1JX0011733TT2', '4', 'G8T1JX0011733TSP', '10', 'G8T1JX0011733TSN', '5', 'G8T1JX0011733TSR', '11', 'G8T1JX0011733TST', '6', 'G8T1JX0011733TSS', '12', 'G8T1JX0011733TSU']
#
# Suspicion: [False, False, False, False, False, False, False, False, False, False, False, False]
#
# Batch Number: NA-
#
# Device Type: Device type not found
#
#
#
#
#
# SerialNumbers: ['May 5 2021', 'G8V190001132AJR) W', 'G8V190001132AFNC', 'G8V190001132AJTR', 'G8V190001132AJUE', 'G8V190001132APN6', 'G8V190001132APN3', 'G8V190001132APG3', 'G8V190001132AJUH', 'G8V190001132AJLC', 'G8V190001132AJU8', 'G8V190001132AJUE', 'G8V190001132AJTG', 'G8V190001132APFD', 'G8V190001132AJM4', 'G8V190001132AJR6', 'G8V190001132APF8', 'G8V190001132AJUN', 'G8V190001132APH7', 'G8V190001132AJMS', 'G8V190001132AJL7', 'G8V190001132AKDX', 'G8V190001132AJTA', 'G8V190001132APNH', 'G8V190001132APJ7']
#
# All Text: ['May 5 2021', 'Pate:', '3/5/2021', 'Line:', '7', 'Shift:', 'Day', 'Blink Mini Camera', 'No', 'SI', 'No', 'oN', 'No', 'SN', '1', 'G8V190001132AJR) W', '9', 'G8V190001132AFNC', '17', 'G8V190001132AJTR', '2', 'G8V190001132AJUE', '10', 'G8V190001132APN6', '18', 'G8V190001132APN3', '3', 'G8V190001132APG3', '11', 'G8V190001132AJUH', '19', 'G8V190001132AJLC', '4', 'G8V190001132AJU8', '12', 'G8V190001132AJUE', '20', 'G8V190001132AJTG', '5', 'G8V190001132APFD', '13', 'G8V190001132AJM4', '21', 'G8V190001132AJR6', '6', 'G8V190001132APF8', '14', 'G8V190001132AJUN', '22', 'G8V190001132APH7', '7', 'G8V190001132AJMS', '15', 'G8V190001132AJL7', '23', 'G8V190001132AKDX', '8', 'G8V190001132AJTA', '16', 'G8V190001132APNH', '24', 'G8V190001132APJ7']
#
# Suspicion: [True, True, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False]
#
# Batch Number: NA-7
#
# Device Type: Blink Mini Camera
#
#
#
#
#
# SerialNumbers: ['G8T1940001640J74', 'G8T1940001640JCF', 'G8T1940001640J3K.', 'G8T1940001640HJA', 'G8T1940001640J83', 'G8T1940001640HRX', 'G8T1940001640HEW', 'G8T1940001640GKT.', 'G8T1940001640HFG.', 'G8T1940001640HP6', 'G8T1940001640HF8', 'G8T1940001640HHM']
#
# All Text: ['Date: 4/22/2020 Line A8 Shift: Night', 'Blink Mini Camera', 'No', 'SN', 'No', 'SN', '1', 'G8T1940001640J74', '7', 'G8T1940001640JCF', '2', 'G8T1940001640J3K.', '8', 'G8T1940001640HJA', '3', 'G8T1940001640J83', '9', 'G8T1940001640HRX', '4', 'G8T1940001640HEW', '10', 'G8T1940001640GKT.', '5', 'G8T1940001640HFG.', '11', 'G8T1940001640HP6', '6', 'G8T1940001640HF8', '12', 'G8T1940001640HHM']
#
# Suspicion: [False, False, True, False, False, False, False, True, True, False, False, False]
#
# Batch Number: NA-
#
# Device Type: Blink Mini Camera
, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False]
#
# Batch Number: NA-7
#
# Device Type: Blink Mini Camera

# %%
# Check to see what the "sloppy" data looks like
for rawText in allText:
    print(rawText, '\n\n')
# Out:
# ['OR', 'Date:', '4/19/2021', 'Line:', 'A17', 'Shift:', 'Day', 'Blink Catalina Camera US', 'No', 'SN', 'No', 'SN', '1', 'G8T1JX00114208BW', '7', 'G8T1JX00114208C4', '2', '8811XX00114208C5', '8', 'G8T1JX00114208C2', '3', 'G8T1JX00114209JA', '9', 'G8T1JX00114208BF', '4', 'G8T1JX00114208BH', '10', 'G8T1JX00114208BR', '5', 'G8T1JX00114208C6', '11', 'G8T1JX00114208BV', '6', 'G8T1JX00114208BT', '12', 'G8T1JX00114208BD']
#
#
# ['Date:', '10/5/2021', 'Line:', '3', 'Shift:', 'Day', 'Blink Catalina', 'No', 'SN', 'No', 'SN', 'No', 'SN', 'x', 'G8V1GH001095MP09', 't', 'G8V1GH001095MPOA', 'X', 'G8V1GH001095MPOR', 'G8V1GH001095MNXU', 'G8V1GH001095MP04', 'A', 'G8V1GH001095MPOE', 'G8V1GH001095MP07', 'G8V1GH001095MPOB', 'X', 'G8V1GH001095MP08', 'h', 'G8V1GH001095MNXX', '&', 'G8V1GH001095MP05', 'X', 'G8V1GH001095MNXT']
#
#
# ['T', 'Date: 2021-05-17 Line: A9 Shift:', 'Day', 'NA Indoor Camcra', 'No', 'SN', 'No', 'SN', '1', 'G8T1JX0011733TT0', '7', 'G8T1JX0011733TSM', '2', 'G8T1JX0011733TSK', '8', 'G8T1JX0011733TSX', '3', 'G8T1JX0011733TSQ', '9', 'G8T1JX0011733TT2', '4', 'G8T1JX0011733TSP', '10', 'G8T1JX0011733TSN', '5', 'G8T1JX0011733TSR', '11', 'G8T1JX0011733TST', '6', 'G8T1JX0011733TSS', '12', 'G8T1JX0011733TSU']
#
#
# ['May 5 2021', 'Date:', '3/5/2021', 'Line:', '7', 'Shift:', 'Day', 'Blink Mini Camera', 'No', 'SI', 'No', 'ON', 'No', 'SN', '1', 'G8V190001132AJR) W', '9', 'G8V190001132AFNC', '17', 'G8V190001132AJTR', '2', 'G8V190001132AJUE', '10', 'G8V190001132APN6', '18', 'G8V190001132APN3', '3', 'G8V190001132APG3', '11', 'G8V190001132AJUH', '19', 'G8V190001132AJLC', '4', 'G8V190001132AJU8', '12', 'G8V190001132AJUE', '20', 'G8V190001132AJTG', '5', 'G8V190001132APFD', '13', 'G8V190001132AJM4', '21', 'G8V190001132AJR6', '6', 'G8V190001132APF8', '14', 'G8V190001132AJUN', '22', 'G8V190001132APH7', '7', 'G8V190001132AJMS', '15', 'G8V190001132AJL7', '23', 'G8V190001132AKDX', '8', 'G8V190001132AJTA', '16', 'G8V190001132APNH', '24', 'G8V190001132APJ7']
#
#
# ['Date: 4/22/2020 Line A8 Shift: Night', 'Blink Mini Camera', 'No', 'SN', 'No', 'SN', '1', 'G8T1940001640J74', '7', 'G8T1940001640JCF', '2', 'G8T1940001640J3K.', '8', 'G8T1940001640HJJA', '3', 'G8T1940001640J83', '9', 'G8T1940001640HRX', '4', 'G8T1940001640HEW', '10', 'G8T1940001640GKT.', '5', 'G8T1940001640HFG.', '11', 'G8T1940001640HP6', '6', 'G8T1940001640HF8', '12', 'G8T1940001640HHM']
#
#
# ['Date:', '5/31/2021', 'Line:', 'A17', 'Shift:', 'Day', 'Blink Mini Camera', 'No', 'SN', 'No', 'SN
# %%
# Alternate method that uses the documnet analysis method (for "table" data)
def extractText(path):
    with open(path, 'rb') as raw_image:
        tempImage = raw_image.read()
        byteImage = bytearray(tempImage)
    response = client.analyze_document(Document = {'Bytes': byteImage}, FeatureTypes = ['TABLES'])
    return response

# %%
extractText(paths[0])
# Out:
# {'DocumentMetadata': {'Pages': 1},
#  'Blocks': [{'BlockType': 'PAGE',
#    'Geometry': {'BoundingBox': {'Width': 0.7846524119377136,
#      'Height': 0.49072569608688354,
#      'Left': 0.0723995491862297,
#      'Top': 0.1815500408411026},
#     'Polygon': [{'X': 0.0723995491862297, 'Y': 0.1994531750679016},
#      {'X': 0.8570519685745239, 'Y': 0.1815500408411026},
#      {'X': 0.8486262559890747, 'Y': 0.672275722026825},
#      {'X': 0.08544255048036575, 'Y': 0.6709693670272827}]},
#    'Id': '5c22d99d-3307-43e0-866e-3888fbdf011f',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['dceffc17-4bbb-46e8-a3f9-8e9173f7ba2e',
#       '7a00a641-1313-4f3f-a6be-d25963048b9e',
#       '8c883c07-25d5-4d93-ba97-0d5dbfb7d1d2',
#       '6c2f0898-b389-4467-ab93-bdbeb9045f1b',
#       'a230fcf6-c821-4fa2-aeee-39a82a3c2724',
#       'af74a08f-ecd4-4b5e-8263-38df773d50a4',
#       '99a6014c-74fe-4990-a5b9-e4bef1e67541',
#       '21ef0744-5dff-4883-9d2a-ebe23b0bd954',
#       '86bf2c69-85ea-49e8-bf8b-31282b4a93e2',
#       'a83b639e-92ec-4112-b638-f2835e79e5ee',
#       'd581213f-c56a-4037-ab02-5b26315d3ae9',
#       '7c687ccf-6494-4bc4-b3b4-8fb4158303a8',
#       'a1643383-77c4-494f-b6ba-c50fc5934fc9',
#       '32c683bd-5293-4608-a3de-910599f77d3f',
#       '0c5fed6d-4319-4b2d-9dda-d0a0710332c9',
#       '5cb90eae-277d-4a03-baf4-2cb4a3083826',
#       'ec21370a-09d5-4775-9840-a05e68595e37',
#       '6253fd8a-3fbe-4112-9ce8-5fa03fbbe3a7',
#       'd72a9c16-2744-45e4-8132-a9c878fce564',
#       'd9a63c0f-c71e-419a-a98b-8a8695a592d1',
#       'af69dc6d-53ad-470c-a001-00cfcbd45401',
#       'a7f1cd1c-89d2-4cbe-bb17-529a4a6e2d99',
#       '5b12de4e-2e81-47ec-aeef-3b826d6240af',
#       '2e458713-5ac6-48c4-98e7-97ff709cdf33',
#       'ff67ff88-15a3-42ff-a902-4acce8b7912b',
#       '69dae879-b02f-4b98-843f-088dcec01265',
#       '8afd7769-3298-426b-bebf-c94b8ac30fcd',
#       '8d0e3f7f-9734-4eac-96aa-67ec958de2f1',
#       '2a9c7b7d-827b-4cab-b266-bf565ec57ba2',
#       '6293e316-fc04-48ad-9730-95f3e670db27',
#       'd513fdb9-102a-4b11-a839-f7b7d248b028',
#       '341b4587-a3d7-4344-bbcf-7551ed2decdf',
#       '406aafcc-d522-4b26-93e1-bda5aac752c0',
#       '761240fd-e2c2-4b74-8c5d-2840d296741a',
#       '6e55478a-9248-470e-a3c8-5ec8f0ae7d8c',
#       'aa027f4f-e4ce-483f-9be0-ac7eab42492a']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.2536392211914,
#    'Text': 'OR',
#    'Geometry': {'BoundingBox': {'Width': 0.057462409138679504,
#      'Height': 0.0811953991651535,
#      'Left': 0.07318330556154251,
#      'Top': 0.22660237550735474},
#     'Polygon': [{'X': 0.07318330556154251, 'Y': 0.22778679430484772},
#      {'X': 0.12868104875087738, 'Y': 0.22660237550735474},
#      {'X': 0.1306457221508026, 'Y': 0.3068487346172333},
#      {'X': 0.07539656013250351, 'Y': 0.30779778957366943}]},
#    'Id': 'dceffc17-4bbb-46e8-a3f9-8e9173f7ba2e',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['4bc07c06-535a-42f2-b801-4897fae59e8a']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 98.96874237060547,
#    'Text': 'Date:',
#    'Geometry': {'BoundingBox': {'Width': 0.044665805995464325,
#      'Height': 0.0219087116420269,
#      'Left': 0.14809858798980713,
#      'Top': 0.2982487976551056},
#     'Polygon': [{'X': 0.14809858798980713, 'Y': 0.29902568459510803},
#      {'X': 0.19232116639614105, 'Y': 0.2982487976551056},
#      {'X': 0.19276438653469086, 'Y': 0.3194299340248108},
#      {'X': 0.14859451353549957, 'Y': 0.3201574981212616}]},
#    'Id': '7a00a641-1313-4f3f-a6be-d25963048b9e',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['cb4ca577-b63e-4dc8-913d-551aa4ffdd7e']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.76244354248047,
#    'Text': '4/19/2021',
#    'Geometry': {'BoundingBox': {'Width': 0.088096022605896,
#      'Height': 0.02581648901104927,
#      'Left': 0.30199363827705383,
#      'Top': 0.2911979556083679},
#     'Polygon': [{'X': 0.30199363827705383, 'Y': 0.2927576005458832},
#      {'X': 0.3898565173149109, 'Y': 0.2911979556083679},
#      {'X': 0.39008966088294983, 'Y': 0.31556642055511475},
#      {'X': 0.30234816670417786, 'Y': 0.3170144557952881}]},
#    'Id': '8c883c07-25d5-4d93-ba97-0d5dbfb7d1d2',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['56c0e7d3-cb3f-47f6-8a8e-310a1d3e6d3f']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 98.82733154296875,
#    'Text': 'Line:',
#    'Geometry': {'BoundingBox': {'Width': 0.04696216061711311,
#      'Height': 0.02232195809483528,
#      'Left': 0.43383920192718506,
#      'Top': 0.29108190536499023},
#     'Polygon': [{'X': 0.43383920192718506, 'Y': 0.2919102907180786},
#      {'X': 0.48070770502090454, 'Y': 0.29108190536499023},
#      {'X': 0.4808013439178467, 'Y': 0.312627911567688},
#      {'X': 0.4339905083179474, 'Y': 0.3134038746356964}]},
#    'Id': '6c2f0898-b389-4467-ab93-bdbeb9045f1b',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['4dbfb357-6c5a-4ca4-8d04-d2be2b950478']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.89527893066406,
#    'Text': 'A17',
#    'Geometry': {'BoundingBox': {'Width': 0.030818089842796326,
#      'Height': 0.021976016461849213,
#      'Left': 0.5257877111434937,
#      'Top': 0.2893536388874054},
#     'Polygon': [{'X': 0.5257877111434937, 'Y': 0.28989893198013306},
#      {'X': 0.5566057562828064, 'Y': 0.2893536388874054},
#      {'X': 0.5566054582595825, 'Y': 0.31081855297088623},
#      {'X': 0.5258253216743469, 'Y': 0.3113296627998352}]},
#    'Id': 'a230fcf6-c821-4fa2-aeee-39a82a3c2724',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['3988e8da-aaba-4360-b069-f7bbf7f04d9b']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.21542358398438,
#    'Text': 'Shift:',
#    'Geometry': {'BoundingBox': {'Width': 0.05867093428969383,
#      'Height': 0.02345426008105278,
#      'Left': 0.6052634119987488,
#      'Top': 0.2854875922203064},
#     'Polygon': [{'X': 0.6053264737129211, 'Y': 0.28653043508529663},
#      {'X': 0.6639343500137329, 'Y': 0.2854875922203064},
#      {'X': 0.6637954115867615, 'Y': 0.30796676874160767},
#      {'X': 0.6052634119987488, 'Y': 0.3089418411254883}]},
#    'Id': 'af74a08f-ecd4-4b5e-8263-38df773d50a4',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['cfc6c0cb-4c87-44ec-b9ad-4ad861c223a9']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.76133728027344,
#    'Text': 'Day',
#    'Geometry': {'BoundingBox': {'Width': 0.031706538051366806,
#      'Height': 0.02535109966993332,
#      'Left': 0.7132627367973328,
#      'Top': 0.28354209661483765},
#     'Polygon': [{'X': 0.7134864926338196, 'Y': 0.28410306572914124},
#      {'X': 0.7449693083763123, 'Y': 0.28354209661483765},
#      {'X': 0.7447003126144409, 'Y': 0.30837222933769226},
#      {'X': 0.7132627367973328, 'Y': 0.3088931739330292}]},
#    'Id': '99a6014c-74fe-4990-a5b9-e4bef1e67541',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['adeea58e-44fe-4ae1-8f4e-57a5687cc60f']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.56388092041016,
#    'Text': 'Blink Catalina Camera US',
#    'Geometry': {'BoundingBox': {'Width': 0.2323893904685974,
#      'Height': 0.025272445753216743,
#      'Left': 0.14966286718845367,
#      'Top': 0.335541307926178},
#     'Polygon': [{'X': 0.14966286718845367, 'Y': 0.33913707733154297},
#      {'X': 0.38183167576789856, 'Y': 0.335541307926178},
#      {'X': 0.3820522427558899, 'Y': 0.35748299956321716},
#      {'X': 0.15017080307006836, 'Y': 0.36081376671791077}]},
#    'Id': '21ef0744-5dff-4883-9d2a-ebe23b0bd954',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['66e954ba-e3d0-444e-a84c-17c293b45e88',
#       'b6295147-cf07-432b-bc1a-e8095b4a059f',
#       '8acc0b5f-20e5-4adf-a9eb-f22930f6da2a',
#       'ba31518d-f5f2-4148-822e-3c0361859705']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.82273864746094,
#    'Text': 'No',
#    'Geometry': {'BoundingBox': {'Width': 0.019610581919550896,
#      'Height': 0.02082056738436222,
#      'Left': 0.16763946413993835,
#      'Top': 0.37544503808021545},
#     'Polygon': [{'X': 0.16763946413993835, 'Y': 0.37570539116859436},
#      {'X': 0.1868109107017517, 'Y': 0.37544503808021545},
#      {'X': 0.1872500479221344, 'Y': 0.3960259258747101},
#      {'X': 0.16810092329978943, 'Y': 0.39626559615135193}]},
#    'Id': '86bf2c69-85ea-49e8-bf8b-31282b4a93e2',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['0825f9dd-88d5-4ed6-9302-4eaa66107e44']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.94609832763672,
#    'Text': 'SN',
#    'Geometry': {'BoundingBox': {'Width': 0.02014320343732834,
#      'Height': 0.020995300263166428,
#      'Left': 0.3328842520713806,
#      'Top': 0.3709874451160431},
#     'Polygon': [{'X': 0.3328842520713806, 'Y': 0.3712599277496338},
#      {'X': 0.3527836799621582, 'Y': 0.3709874451160431},
#      {'X': 0.35302746295928955, 'Y': 0.39173170924186707},
#      {'X': 0.33315154910087585, 'Y': 0.3919827342033386}]},
#    'Id': 'a83b639e-92ec-4112-b638-f2835e79e5ee',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['9b8b2458-5054-4df8-9823-7c8416601d5b']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.77265167236328,
#    'Text': 'No',
#    'Geometry': {'BoundingBox': {'Width': 0.019819436594843864,
#      'Height': 0.021151574328541756,
#      'Left': 0.5014356374740601,
#      'Top': 0.3693673610687256},
#     'Polygon': [{'X': 0.5014356374740601, 'Y': 0.36963748931884766},
#      {'X': 0.521212637424469, 'Y': 0.3693673610687256},
#      {'X': 0.5212550759315491, 'Y': 0.3902701437473297},
#      {'X': 0.5015017986297607, 'Y': 0.3905189633369446}]},
#    'Id': 'd581213f-c56a-4037-ab02-5b26315d3ae9',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['fecef440-7688-4de7-a362-14fab8322bde']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.93756103515625,
#    'Text': 'SN',
#    'Geometry': {'BoundingBox': {'Width': 0.02101682312786579,
#      'Height': 0.022288614884018898,
#      'Left': 0.6555094718933105,
#      'Top': 0.3639131486415863},
#     'Polygon': [{'X': 0.6556355357170105, 'Y': 0.36420199275016785},
#      {'X': 0.6765263080596924, 'Y': 0.3639131486415863},
#      {'X': 0.6763736009597778, 'Y': 0.385936439037323},
#      {'X': 0.6555094718933105, 'Y': 0.38620173931121826}]},
#    'Id': '7c687ccf-6494-4bc4-b3b4-8fb4158303a8',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['0ba1f928-45f5-4258-8bea-ad0d722618d0']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 95.345947265625,
#    'Text': '1',
#    'Geometry': {'BoundingBox': {'Width': 0.006326843984425068,
#      'Height': 0.019098838791251183,
#      'Left': 0.1755443811416626,
#      'Top': 0.41524702310562134},
#     'Polygon': [{'X': 0.1755443811416626, 'Y': 0.415315181016922},
#      {'X': 0.18145820498466492, 'Y': 0.41524702310562134},
#      {'X': 0.1818712204694748, 'Y': 0.434283584356308},
#      {'X': 0.17596378922462463, 'Y': 0.4343458414077759}]},
#    'Id': 'a1643383-77c4-494f-b6ba-c50fc5934fc9',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['8089dfdc-4352-4449-b355-6e55cba63ff7']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 61.16426086425781,
#    'Text': 'G8T1JX00114208BW',
#    'Geometry': {'BoundingBox': {'Width': 0.15073980391025543,
#      'Height': 0.025123821571469307,
#      'Left': 0.2706212103366852,
#      'Top': 0.40953928232192993},
#     'Polygon': [{'X': 0.2706212103366852, 'Y': 0.411297082901001},
#      {'X': 0.42117685079574585, 'Y': 0.40953928232192993},
#      {'X': 0.4213609993457794, 'Y': 0.4330885708332062},
#      {'X': 0.2710075080394745, 'Y': 0.4346630871295929}]},
#    'Id': '32c683bd-5293-4608-a3de-910599f77d3f',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['06480793-f72a-4955-8c1c-515721b11777']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.95890808105469,
#    'Text': '7',
#    'Geometry': {'BoundingBox': {'Width': 0.009531361982226372,
#      'Height': 0.019981099292635918,
#      'Left': 0.5072500109672546,
#      'Top': 0.40939944982528687},
#     'Polygon': [{'X': 0.5072500109672546, 'Y': 0.40950971841812134},
#      {'X': 0.5167357921600342, 'Y': 0.40939944982528687},
#      {'X': 0.5167813897132874, 'Y': 0.42927998304367065},
#      {'X': 0.5073064565658569, 'Y': 0.42938053607940674}]},
#    'Id': '0c5fed6d-4319-4b2d-9dda-d0a0710332c9',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['7228ab4a-1567-4840-aefe-d0d11c0806fd']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 96.12010955810547,
#    'Text': 'G8T1JX00114208C4',
#    'Geometry': {'BoundingBox': {'Width': 0.16071467101573944,
#      'Height': 0.026546796783804893,
#      'Left': 0.5856695771217346,
#      'Top': 0.40338268876075745},
#     'Polygon': [{'X': 0.5857114195823669, 'Y': 0.40527766942977905},
#      {'X': 0.7463842034339905, 'Y': 0.40338268876075745},
#      {'X': 0.7461110353469849, 'Y': 0.4282376170158386},
#      {'X': 0.5856695771217346, 'Y': 0.4299294650554657}]},
#    'Id': '5cb90eae-277d-4a03-baf4-2cb4a3083826',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['5c7d520b-afc0-4161-9096-8a523b932ffa']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.92048645019531,
#    'Text': '2',
#    'Geometry': {'BoundingBox': {'Width': 0.009806581772863865,
#      'Height': 0.019274400547146797,
#      'Left': 0.17481251060962677,
#      'Top': 0.454392671585083},
#     'Polygon': [{'X': 0.17481251060962677, 'Y': 0.45448189973831177},
#      {'X': 0.18420477211475372, 'Y': 0.454392671585083},
#      {'X': 0.18461909890174866, 'Y': 0.4735872745513916},
#      {'X': 0.17523708939552307, 'Y': 0.47366708517074585}]},
#    'Id': 'ec21370a-09d5-4775-9840-a05e68595e37',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['3027bb7d-c2ed-4701-9550-060b8d952f25']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 29.23785400390625,
#    'Text': '8811XX00114208C5',
#    'Geometry': {'BoundingBox': {'Width': 0.14548973739147186,
#      'Height': 0.02462010271847248,
#      'Left': 0.27379801869392395,
#      'Top': 0.4500368535518646},
#     'Polygon': [{'X': 0.27379801869392395, 'Y': 0.45143285393714905},
#      {'X': 0.4191015064716339, 'Y': 0.4500368535518646},
#      {'X': 0.4192877411842346, 'Y': 0.4734363853931427},
#      {'X': 0.27417856454849243, 'Y': 0.47465696930885315}]},
#    'Id': '6253fd8a-3fbe-4112-9ce8-5fa03fbbe3a7',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['2a493aee-552e-45a7-adb8-76d22abbca24']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.90764617919922,
#    'Text': '8',
#    'Geometry': {'BoundingBox': {'Width': 0.009509989991784096,
#      'Height': 0.019685281440615654,
#      'Left': 0.5075550675392151,
#      'Top': 0.4496738612651825},
#     'Polygon': [{'X': 0.5075550675392151, 'Y': 0.44976451992988586},
#      {'X': 0.5170203447341919, 'Y': 0.4496738612651825},
#      {'X': 0.5170650482177734, 'Y': 0.4692780077457428},
#      {'X': 0.5076104998588562, 'Y': 0.4693591296672821}]},
#    'Id': 'd72a9c16-2744-45e4-8132-a9c878fce564',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['a108a676-d07f-4f03-bb23-4e06d2ac890b']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 96.08761596679688,
#    'Text': 'G8T1JX00114208C2',
#    'Geometry': {'BoundingBox': {'Width': 0.1597871333360672,
#      'Height': 0.025437014177441597,
#      'Left': 0.5860636234283447,
#      'Top': 0.4446577727794647},
#     'Polygon': [{'X': 0.5861048102378845, 'Y': 0.44621050357818604},
#      {'X': 0.7458507418632507, 'Y': 0.4446577727794647},
#      {'X': 0.7455862164497375, 'Y': 0.46873730421066284},
#      {'X': 0.5860636234283447, 'Y': 0.47009479999542236}]},
#    'Id': 'd9a63c0f-c71e-419a-a98b-8a8695a592d1',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['

#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['8266425d-cfd4-456e-b3bb-f14c5a4b5ed3']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.74246215820312,
#    'Text': '11',
#    'Geometry': {'BoundingBox': {'Width': 0.015878787264227867,
#      'Height': 0.019161047413945198,
#      'Left': 0.5057567954063416,
#      'Top': 0.5675588846206665},
#     'Polygon': [{'X': 0.5057567954063416, 'Y': 0.5676156282424927},
#      {'X': 0.5215967297554016, 'Y': 0.5675588846206665},
#      {'X': 0.5216355323791504, 'Y': 0.5866786241531372},
#      {'X': 0.5058131814002991, 'Y': 0.5867199301719666}]},
#    'Id': 'd513fdb9-102a-4b11-a839-f7b7d248b028',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['bd461ede-a044-4fa8-9d3d-b4bb8f1fda99']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 97.00877380371094,
#    'Text': 'G8T1JX00114208BV',
#    'Geometry': {'BoundingBox': {'Width': 0.15981994569301605,
#      'Height': 0.024546219035983086,
#      'Left': 0.5859876275062561,
#      'Top': 0.5643994212150574},
#     'Polygon': [{'X': 0.5860291123390198, 'Y': 0.5649908185005188},
#      {'X': 0.7458075284957886, 'Y': 0.5643994212150574},
#      {'X': 0.74554044008255, 'Y': 0.5885487198829651},
#      {'X': 0.5859876275062561, 'Y': 0.5889456272125244}]},
#    'Id': '341b4587-a3d7-4344-bbcf-7551ed2decdf',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['a6f315a5-1ca0-44de-8e56-ffc51db98a56']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.74185180664062,
#    'Text': '6',
#    'Geometry': {'BoundingBox': {'Width': 0.01010525319725275,
#      'Height': 0.01968589425086975,
#      'Left': 0.1790492981672287,
#      'Top': 0.608976423740387},
#     'Polygon': [{'X': 0.1790492981672287, 'Y': 0.6089909672737122},
#      {'X': 0.1887310892343521, 'Y': 0.608976423740387},
#      {'X': 0.18915455043315887, 'Y': 0.6286575794219971},
#      {'X': 0.17948369681835175, 'Y': 0.6286622881889343}]},
#    'Id': '406aafcc-d522-4b26-93e1-bda5aac752c0',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['77a2b2ea-635b-41fa-8f5f-9a159d398b75']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 95.42316436767578,
#    'Text': 'G8T1JX00114208BT',
#    'Geometry': {'BoundingBox': {'Width': 0.15542176365852356,
#      'Height': 0.02456657402217388,
#      'Left': 0.2692837417125702,
#      'Top': 0.6061106324195862},
#     'Polygon': [{'X': 0.2692837417125702, 'Y': 0.6063638925552368},
#      {'X': 0.4245164096355438, 'Y': 0.6061106324195862},
#      {'X': 0.42470550537109375, 'Y': 0.6306184530258179},
#      {'X': 0.26969218254089355, 'Y': 0.6306772232055664}]},
#    'Id': '761240fd-e2c2-4b74-8c5d-2840d296741a',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['50272812-167c-4258-9283-07c2ac84b283']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 99.94771575927734,
#    'Text': '12',
#    'Geometry': {'BoundingBox': {'Width': 0.01748923398554325,
#      'Height': 0.01993388682603836,
#      'Left': 0.5059846639633179,
#      'Top': 0.6061695218086243},
#     'Polygon': [{'X': 0.5059846639633179, 'Y': 0.6061978340148926},
#      {'X': 0.5234355330467224, 'Y': 0.6061695218086243},
#      {'X': 0.5234739184379578, 'Y': 0.6260928511619568},
#      {'X': 0.5060433149337769, 'Y': 0.626103401184082}]},
#    'Id': '6e55478a-9248-470e-a3c8-5ec8f0ae7d8c',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['207c87c3-bcbb-4ba1-a1e0-093804a4bd00']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 97.03677368164062,
#    'Text': 'G8T1JX00114208BD',
#    'Geometry': {'BoundingBox': {'Width': 0.1603529304265976,
#      'Height': 0.02385990135371685,
#      'Left': 0.5862035155296326,
#      'Top': 0.6046024560928345},
#     'Polygon': [{'X': 0.5862447619438171, 'Y': 0.6048718690872192},
#      {'X': 0.7465564608573914, 'Y': 0.6046024560928345},
#      {'X': 0.7462917566299438, 'Y': 0.6283846497535706},
#      {'X': 0.5862035155296326, 'Y': 0.6284623742103577}]},
#    'Id': 'aa027f4f-e4ce-483f-9be0-ac7eab42492a',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['611c1b6e-61d7-424c-b247-73b25b3988a1']}]},
#   {'BlockType': 'WORD',
#    'Confidence': 99.2536392211914,
#    'Text': 'OR',
#    'TextType': 'HANDWRITING',
#    'Geometry': {'BoundingBox': {'Width': 0.057462409138679504,
#      'Height': 0.0811953991651535,
#      'Left': 0.07318330556154251,
#      'Top': 0.22660237550735474},
#     'Polygon': [{'X': 0.07318330556154251, 'Y': 0.22778679430484772},
#      {'X': 0.12868104875087738, 'Y': 0.22660237550735474},
#      {'X': 0.1306457221508026, 'Y': 0.3068487346172333},
#      {'X': 0.07539656013250351, 'Y': 0.30779778957366943}]},
#    'Id': '4bc07c06-535a-42f2-b801-4897fae59e8a'},
#   {'BlockType': 'WORD',
#    'Confidence': 98.96874237060547,
#    'Text': 'Date:',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.044665805995464325,
#      'Height': 0.021908694878220558,
#      'Left': 0.14809858798980713,
#      'Top': 0.2982487976551056},
#     'Polygon': [{'X': 0.14809858798980713, 'Y': 0.29902568459510803},
#      {'X': 0.19232116639614105, 'Y': 0.2982487976551056},
#      {'X': 0.19276438653469086, 'Y': 0.3194299340248108},
#      {'X': 0.14859451353549957, 'Y': 0.3201574981212616}]},
#    'Id': 'cb4ca577-b63e-4dc8-913d-551aa4ffdd7e'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.76244354248047,
#    'Text': '4/19/2021',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.088096022605896,
#      'Height': 0.02581649087369442,
#      'Left': 0.30199363827705383,
#      'Top': 0.2911979556083679},
#     'Polygon': [{'X': 0.30199363827705383, 'Y': 0.2927576005458832},
#      {'X': 0.3898565173149109, 'Y': 0.2911979556083679},
#      {'X': 0.39008966088294983, 'Y': 0.31556642055511475},
#      {'X': 0.30234816670417786, 'Y': 0.3170144557952881}]},
#    'Id': '56c0e7d3-cb3f-47f6-8a8e-310a1d3e6d3f'},
#   {'BlockType': 'WORD',
#    'Confidence': 98.82733154296875,
#    'Text': 'Line:',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.04696216434240341,
#      'Height': 0.02232195809483528,
#      'Left': 0.43383920192718506,
#      'Top': 0.29108190536499023},
#     'Polygon': [{'X': 0.43383920192718506, 'Y': 0.2919102907180786},
#      {'X': 0.48070770502090454, 'Y': 0.29108190536499023},
#      {'X': 0.48080137372016907, 'Y': 0.312627911567688},
#      {'X': 0.4339905083179474, 'Y': 0.3134038746356964}]},
#    'Id': '4dbfb357-6c5a-4ca4-8d04-d2be2b950478'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.89527893066406,
#    'Text': 'A17',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.
},
#   {'BlockType': 'WORD',
#    'Confidence': 99.95890808105469,
#    'Text': '7',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.009531360119581223,
#      'Height': 0.019981099292635918,
#      'Left': 0.5072500109672546,
#      'Top': 0.40939944982528687},
#     'Polygon': [{'X': 0.5072500109672546, 'Y': 0.40950971841812134},
#      {'X': 0.5167357921600342, 'Y': 0.40939944982528687},
#      {'X': 0.5167813897132874, 'Y': 0.42927998304367065},
#      {'X': 0.5073064565658569, 'Y': 0.42938053607940674}]},
#    'Id': '7228ab4a-1567-4840-aefe-d0d11c0806fd'},
#   {'BlockType': 'WORD',
#    'Confidence': 96.12010955810547,
#    'Text': 'G8T1JX00114208C4',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.16071470081806183,
#      'Height': 0.026546798646450043,
#      'Left': 0.5856695771217346,
#      'Top': 0.40338268876075745},
#     'Polygon': [{'X': 0.5857114195823669, 'Y': 0.40527766942977905},
#      {'X': 0.7463842630386353, 'Y': 0.40338268876075745},
#      {'X': 0.7461110949516296, 'Y': 0.4282376170158386},
#      {'X': 0.5856695771217346, 'Y': 0.4299294650554657}]},
#    'Id': '5c7d520b-afc0-4161-9096-8a523b932ffa'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.92048645019531,
#    'Text': '2',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.009806578978896141,
#      'Height': 0.019274361431598663,
#      'Left': 0.17481251060962677,
#      'Top': 0.454392671585083},
#     'Polygon': [{'X': 0.17481251060962677, 'Y': 0.45448189973831177},
#      {'X': 0.18420475721359253, 'Y': 0.454392671585083},
#      {'X': 0.18461909890174866, 'Y': 0.4735872447490692},
#      {'X': 0.17523708939552307, 'Y': 0.47366705536842346}]},
#    'Id': '3027bb7d-c2ed-4701-9550-060b8d952f25'},
#   {'BlockType': 'WORD',
#    'Confidence': 29.23785400390625,
#    'Text': '8811XX00114208C5',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.14548975229263306,
#      'Height': 0.02462010830640793,
#      'Left': 0.27379801869392395,
#      'Top': 0.4500368535518646},
#     'Polygon': [{'X': 0.27379801869392395, 'Y': 0.45143285393714905},
#      {'X': 0.4191015064716339, 'Y': 0.4500368535518646},
#      {'X': 0.419287770986557, 'Y': 0.4734363853931427},
#      {'X': 0.27417856454849243, 'Y': 0.47465696930885315}]},
#    'Id': '2a493aee-552e-45a7-adb8-76d22abbca24'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.90764617919922,
#    'Text': '8',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.009509974159300327,
#      'Height': 0.01968528889119625,
#      'Left': 0.5075550675392151,
#      'Top': 0.4496738612651825},
#     'Polygon': [{'X': 0.5075550675392151, 'Y': 0.44976451992988586},
#      {'X': 0.5170203447341919, 'Y': 0.4496738612651825},
#      {'X': 0.5170650482177734, 'Y': 0.4692780077457428},
#      {'X': 0.5076104998588562, 'Y': 0.4693591296672821}]},
#    'Id': 'a108a676-d07f-4f03-bb23-4e06d2ac890b'},
#   {'BlockType': 'WORD',
#    'Confidence': 96.08761596679688,
#    'Text': 'G8T1JX00114208C2',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.15978705883026123,
#      'Height': 0.025437025353312492,
#      'Left': 0.5860636234283447,
#      'Top': 0.4446577727794647},
#     'Polygon': [{'X': 0.5861048102378845, 'Y': 0.44621050357818604},
#      {'X': 0.745850682258606, 'Y': 0.4446577727794647},
#      {'X': 0.7455861568450928, 'Y': 0.46873730421066284},
#      {'X': 0.5860636234283447, 'Y': 0.47009479999542236}]},
#    'Id': 'cbda3d15-d485-407b-b5f0-aadb0676366c'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.76750946044922,
#    'Text': '3',
#    'TextType': 'HANDWRITING',
#    'Geometry': {'BoundingBox': {'Width': 0.009419658221304417,
#      'Height': 0.019729608669877052,
#      'Left': 0.17644071578979492,
#      'Top': 0.4929882884025574},
#     'Polygon': [{'X': 0.17644071578979492, 'Y': 0.4930557608604431},
#      {'X': 0.1854362040758133, 'Y': 0.4929882884025574},
#      {'X': 0.18586038053035736, 'Y': 0.5126596093177795},
#      {'X': 0.17687496542930603, 'Y': 0.5127179026603699}]},
#    'Id': '5d7d4d4a-ce8c-4290-948a-fdbea91314a0'},
#   {'BlockType': 'WORD',
#    'Confidence': 76.07565307617188,
#    'Text': 'G8T1JX00114209JA',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.154672309756279,
#      'Height': 0.024387413635849953,
#      'Left': 0.26746460795402527,
#      'Top': 0.48901811242103577},
#     'Polygon': [{'X': 0.26746460795402527, 'Y': 0.4901944398880005},
#      {'X': 0.4219541847705841, 'Y': 0.48901811242103577},
#      {'X': 0.42213693261146545, 'Y': 0.5124152302742004},
#      {'X': 0.26785436272621155, 'Y': 0.5134055018424988}]},
#    'Id': '296bbdfb-6c94-4113-b25e-65a9ad4e31d1'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.88569641113281,
#    'Text': '9',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.009753573685884476,
#      'Height': 0.01980438083410263,
#      'Left': 0.5077134966850281,
#      'Top': 0.488468199968338},
#     'Polygon': [{'X': 0.5077134966850281, 'Y': 0.4885420501232147},
#      {'X': 0.5174224376678467, 'Y': 0.488468199968338},
#      {'X': 0.5174670815467834, 'Y': 0.5082085728645325},
#      {'X': 0.5077692866325378, 'Y': 0.5082725882530212}]},
#    'Id': '50bf6c75-0083-4032-b124-88ed1e5deb66'},
#   {'BlockType': 'WORD',
#    'Confidence': 83.09225463867188,
#    'Text': 'G8T1JX00114208BF',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.15560287237167358,
#      'Height': 0.02467917464673519,
#      'Left': 0.5888557434082031,
#      'Top': 0.48448726534843445},
#     'Polygon': [{'X': 0.5889001488685608, 'Y': 0.4856879413127899},
#      {'X': 0.7444586157798767, 'Y': 0.48448726534843445},
#      {'X': 0.7441999316215515, 'Y': 0.508152186870575},
#      {'X': 0.5888557434082031, 'Y': 0.509166419506073}]},
#    'Id': '416fb0d6-c30f-432a-9dd3-1c038d597450'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.60897827148438,
#    'Text': '4',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.009290507063269615,
#      'Height': 0.019131699576973915,
#      'Left': 0.1771424114704132,
#      'Top': 0.531668484210968},
#     'Polygon': [{'X': 0.1771424114704132, 'Y': 0.5317173004150391},
#      {'X': 0.18602098524570465, 'Y': 0.531668484210968},
#      {'X': 0.18643292784690857, 'Y': 0.5507601499557495},
#      {'X': 0.17756403982639313, 'Y': 0.5508001446723938}]},
#    'Id': 'a30df05f-2233-4ef9-aa0e-ae4c4ddac41c'},
#   {'BlockType': 'WORD',
#    'Confidence': 91.34757995605469,
#    'Text': 'G8T1JX00114208BH',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.15354280173778534,
#      'Height': 0.02407289668917656,
#      'Left': 0.2697950601577759,
#      'Top': 0.527875542640686},
#     'Polygon': [{'X': 0.2697950601577759, 'Y': 0.5287387371063232},
#      {'X': 0.42315635085105896, 'Y': 0.527875542640686},
#      {'X': 0.4233378767967224, 'Y': 0.5512694716453552},
#      {'X': 0.2701825201511383, 'Y': 0.5519484281539917}]},
#    'Id': '256d413d-ed0e-4cfc-800c-47456d017054'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.89781951904297,
#    'Text': '10',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.016728585585951805,
#      'Height': 0.019573070108890533,
#      'Left': 0.505961537361145,
#      'Top': 0.5275335907936096},
#     'Polygon': [{'X': 0.505961537361145, 'Y': 0.5276273488998413},
#      {'X': 0.5226518511772156, 'Y': 0.5275335907936096},
#      {'X': 0.5226901173591614, 'Y': 0.5470294952392578},
#      {'X': 0.5060186982154846, 'Y': 0.5471066236495972}]},
#    'Id': '0b668098-54b9-4b6e-8e1b-2e5b5bd1a23d'},
#   {'BlockType': 'WORD',
#    'Confidence': 97.09446716308594,
#    'Text': 'G8T1JX00114208BR',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.16142535209655762,
#      'Height': 0.02504563517868519,
#      'Left': 0.585009753704071,
#      'Top': 0.5239987969398499},
#     'Polygon': [{'X': 0.585050106048584, 'Y': 0.5249238610267639},
#      {'X': 0.7464351058006287, 'Y': 0.5239987969398499},
#      {'X': 0.746165931224823, 'Y': 0.5483176708221436},
#      {'X': 0.585009753704071, 'Y': 0.5490444302558899}]},
#    'Id': 'f4f6f2d9-4f40-4613-9438-9b93e4287208'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.99581909179688,
#    'Text': '5',
#    'TextType': 'HANDWRITING',
#    'Geometry': {'BoundingBox': {'Width': 0.00961883645504713,
#      'Height': 0.01967111974954605,
#      'Left': 0.1782345473766327,
#      'Top': 0.5704031586647034},
#     'Polygon': [{'X': 0.1782345473766327, 'Y': 0.5704353451728821},
#      {'X': 0.18743008375167847, 'Y': 0.5704031586647034},
#      {'X': 0.1878533810377121, 'Y': 0.5900514721870422},
#      {'X': 0.17866818606853485, 'Y': 0.5900743007659912}]},
#    'Id': '1dd4e8c9-c94c-440a-a5a8-0f89120eec26'},
#   {'BlockType': 'WORD',
#    'Confidence': 94.69786071777344,
#    'Text': 'G8T1JX00114208C6',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.15547168254852295,
#      'Height': 0.02475760504603386,
#      'Left': 0.2699292302131653,
#      'Top': 0.5669607520103455},
#     'Polygon': [{'X': 0.2699292302131653, 'Y': 0.5675246715545654},
#      {'X': 0.4252142012119293, 'Y': 0.5669607520103455},
#      {'X': 0.42540091276168823, 'Y': 0.5913484692573547},
#      {'X': 0.27033382654190063, 'Y': 0.5917183756828308}]},
#    'Id': '8266425d-cfd4-456e-b3bb-f14c5a4b5ed3'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.74246215820312,
#    'Text': '11',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.015878794714808464,
#      'Height': 0.019161053001880646,
#      'Left': 0.5057567954063416,
#      'Top': 0.5675588846206665},
#     'Polygon': [{'X': 0.5057567954063416, 'Y': 0.5676156282424927},
#      {'X': 0.5215967893600464, 'Y': 0.5675588846206665},
#      {'X': 0.5216355919837952, 'Y': 0.5866786241531372},
#      {'X': 0.5058131814002991, 'Y': 0.5867199301719666}]},
#    'Id': 'bd461ede-a044-4fa8-9d3d-b4bb8f1fda99'},
#   {'BlockType': 'WORD',
#    'Confidence': 97.00877380371094,
#    'Text': 'G8T1JX00114208BV',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.15981990098953247,
#      'Height': 0.024546222761273384,
#      'Left': 0.5859876275062561,
#      'Top': 0.5643994212150574},
#     'Polygon': [{'X': 0.5860291123390198, 'Y': 0.5649908185005188},
#      {'X': 0.7458075284957886, 'Y': 0.5643994212150574},
#      {'X': 0.74554044008255, 'Y': 0.5885487198829651},
#      {'X': 0.5859876275062561, 'Y': 0.5889456272125244}]},
#    'Id': 'a6f315a5-1ca0-44de-8e56-ffc51db98a56'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.74185180664062,
#    'Text': '6',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.010105252265930176,
#      'Height': 0.01968587562441826,
#      'Left': 0.1790492981672287,
#      'Top': 0.608976423740387},
#     'Polygon': [{'X': 0.1790492981672287, 'Y': 0.6089909672737122},
#      {'X': 0.1887310892343521, 'Y': 0.608976423740387},
#      {'X': 0.18915455043315887, 'Y': 0.6286575794219971},
#      {'X': 0.17948369681835175, 'Y': 0.6286622881889343}]},
#    'Id': '77a2b2ea-635b-41fa-8f5f-9a159d398b75'},
#   {'BlockType': 'WORD',
#    'Confidence': 95.42316436767578,
#    'Text': 'G8T1JX00114208BT',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.15542176365852356,
#      'Height': 0.02456657774746418,
#      'Left': 0.2692837417125702,
#      'Top': 0.6061106324195862},
#     'Polygon': [{'X': 0.2692837417125702, 'Y': 0.6063638925552368},
#      {'X': 0.4245164394378662, 'Y': 0.6061106324195862},
#      {'X': 0.42470550537109375, 'Y': 0.6306184530258179},
#      {'X': 0.26969218254089355, 'Y': 0.6306772232055664}]},
#    'Id': '50272812-167c-4258-9283-07c2ac84b283'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.94771575927734,
#    'Text': '12',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.017489293590188026,
#      'Height': 0.019933924078941345,
#      'Left': 0.5059846639633179,
#      'Top': 0.6061695218086243},
#     'Polygon': [{'X': 0.5059846639633179, 'Y': 0.6061978340148926},
#      {'X': 0.5234355926513672, 'Y': 0.6061695218086243},
#      {'X': 0.5234739780426025, 'Y': 0.6260928511619568},
#      {'X': 0.5060433149337769, 'Y': 0.6261034607887268}]},
#    'Id': '207c87c3-bcbb-4ba1-a1e0-093804a4bd00'},
#   {'BlockType': 'WORD',
#    'Confidence': 97.03677368164062,
#    'Text': 'G8T1JX00114208BD',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.1603529304265976,
#      'Height': 0.02385990135371685,
#      'Left': 0.5862035155296326,
#      'Top': 0.6046024560928345},
#     'Polygon': [{'X': 0.5862447619438171, 'Y': 0.6048718690872192},
#      {'X': 0.7465564608573914, 'Y': 0.6046024560928345},
#      {'X': 0.7462917566299438, 'Y': 0.6283846497535706},
#      {'X': 0.5862035155296326, 'Y': 0.6284623742103577}]},
#    'Id': '611c1b6e-61d7-424c-b247-73b25b3988a1'}],
#  'DetectDocumentTextModelVersion': '1.0',
#  'ResponseMetadata': {'RequestId': 'fc763959-dd37-4a5d-9426-df62a8eb1c02',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'fc763959-dd37-4a5d-9426-df62a8eb1c02',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '40106',
#    'date': 'Tue, 15 Jun 2021 21:36:09 GMT'},
#   'RetryAttempts': 0}}
