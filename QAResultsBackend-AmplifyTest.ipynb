# %%
# Imports
import boto3
import pandas as pd
import numpy as np
import pymysql
import datetime as dt
import aurora_data_api # https://github.com/cloud-utils/aurora-data-api


# Data Visualization/Analysis
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Crucial Information
port = 3306
user = 'admin'
password = 'password'

# Credentials to access a3
host = 'amplifytestdb.cluster-cyvmmsfjcmrl.us-east-1.rds.amazonaws.com'
dbName = 'db'
a_ARN = 'arn:aws:rds:us-east-1:319481862133:cluster:amplifytestdb'
s_ARN = 'arn:aws:secretsmanager:us-east-1:319481862133:secret:amplifytestKey-8Lcy2H'

# %%
# Connect to DB
db = aurora_data_api.connect(aurora_cluster_arn = a_ARN, secret_arn=s_ARN, database=dbName)
c = db.cursor()

# Connect to m1
# db = pymysql.connect(host = host4, port = port, user = user, password = password, autocommit = True)
# c = db.cursor()

# %%
# General helper methods
def getDate():
    return dt.datetime.today().strftime('%Y-%m-%d') # YYYY-MM-DD


# Execute queries + display results
#def execute(q):
#     global db, c
# #     db = aurora_data_api.connect(aurora_cluster_arn = a3_ARN, secret_arn=sA3_ARN, database=dbName3)
# #     c = db.cursor()
#     try:
#         c.execute(q) # Execute the query
#         db.commit()
#         return c.fetchall() # Display the output of said query
#     except Exception as e:
#         try:
#             print('Original error:', e)
#             db = aurora_data_api.connect(aurora_cluster_arn = a3_ARN, secret_arn=sA3_ARN, database=dbName3)
#             c = db.cursor()
#             c.execute(q) # Execute the query
#             db.commit()
#             return c.fetchall() # Display the output of said query
#         except Exception as newE:
#             print('Error with execute:', newE)

def execute(q):
    try:
        db = aurora_data_api.connect(aurora_cluster_arn = a_ARN, secret_arn=s_ARN, database=dbName)
        c = db.cursor()
        c.execute(q) # Execute the query
        db.commit()
        return c.fetchall() # Display the output of said query
    except Exception as newE:
        print('Error with execute:', newE)
# Create the initial QA Table
def createQATable():
    q = '''
        Create table if not exists QAResults(
            SerialNumber VARCHAR(30),
            BatchNumber VARCHAR(30),
            Date VARCHAR(10),
            Tester VARCHAR(20),
            FunctionalTest VARCHAR(4),
            FailureType text,
            LogMessage text,
            primary key (SerialNumber)
        )
    '''
    try:
        execute(q)
    except Exception as e:
        print('Issue with table creation:', e)

# Delete the QAResults table
def deleteTable():
    try:
        q = ''' DROP Table QAResults '''
        c.execute(q)
    except Exception as e:
        print('Error with deleting the table:', e)
        
# Helper method to get an entry (based off of SN alone)
def getEntry(sn):
    try:
        q = ''' SELECT * FROM QAResults where SerialNumber = '{}' '''.format(sn)
        #cursor1.execute(q)
        return execute(q)
    except Exception as e:
        print('Issue with get entry:', e)

# Helper method to insert an entry
def insertEntry(sn, bn, ft, tst, msg, fail = None, date = getDate()):
    try:
        q = ''' Insert into QAResults values ('%s', '%s', '%s', '%s', '%s', '%s', '%s')''' % (sn, bn, date, tst, ft, fail, msg)
        return execute(q)
        #executeQuery(q)
    except Exception as e:
        print('Issue with add entry:', e)

# Delete an entry based on SN alone
def deleteEntry(sn):
    try:
        q = ''' Delete from QAResults where SerialNumber = '%s' ''' % (sn)
        #cursor1.execute(q)
        return execute(q)
    except Exception as e:
        print('Issue with delete entry:', e)

# Modify a field based off of SN
def modifyEntry(sn, field, newVal):
    try:
        q = ''' Update QAResults set {} = '{}' where SerialNumber = '{}' '''.format(field, newVal,sn)
        #cursor1.execute(q)
        return execute(q)
    except Exception as e:
        print('Issue with edit entry:', e)

# Get all the results for the table
def displayAll():
    try:
        print('\n\nQAResults Table\n')
        q = ''' Select * From QAResults '''
        display(execute(q))
    except Exception as e:
        print('Issue with displaying table:', e)
        

# Convert into the tabular form... powerful
def convertToDF(tbl):
    try:
        db = aurora_data_api.connect(aurora_cluster_arn = a3_ARN, secret_arn=sA3_ARN, database=dbName3)
        df1 = pd.read_sql('''SELECT * FROM {} '''.format(tbl), con = db)
        return df1
    except Exception as e:
        print('error:', e)

def insertFew():
    insertEntry('EEE833134W-0', 'E2', 'Pass', 'Zach', 'Everything works', 't1')
    insertEntry('EEE833134W-1', 'E2', 'Fail', 'Ruohan','Everything works', 't2')
    insertEntry('EEE833134W-2', 'E2','Fail', 'Ryan','Breakdown occurred', 't3')

def insertMid(n):
    snPrefix = ['EUHWQ3931-', 'ABC22', 'RRH43144', '283367144']
    batchNums = ['EE1', 'FF2', 'GG3']
    testers = ['Zach', 'Ryan', 'Ruohan', 'Nikki', 'Megan']
    results = ['Pass', 'Fail']
    dates = [getDate(), '2020-05-02', '2020-06-09', '2019-11-27', '2021-04-19', '2021-04-01']
    messages = ['Camera is not doing so hot', 'Night mode issue ensued', 'Other issue-unlisted']
    passMsg = 'Everything works'
    for i in range(n):
        sn = snPrefix[i % 4] + str(i)
        bn = batchNums[i % 3]
        t = testers[i % 5]
        res = results[int(i % 4 == 0)]
        d = dates[i % 6]
        if res == 'Pass':
            fail = failureTypes[0]
            msg = passMsg
        else:
            fail = failureTypes[i % 3 + 1] if i < 20 else failureTypes[i % 5 + 1] 
            msg = messages[i % 3]
        insertEntry(sn, bn, res, t, msg, fail, d)

def insertMany():
    sampleDates1 = ['2020-12-15', '2021-01-15', '2021-02-15', '2021-03-15', '2021-04-15', '2021-05-15', '2021-06-15']
    sampleDates2 = ['2020-12-25', '2021-01-25', '2020-12-25', '2021-03-25', '2021-04-25', '2021-05-25', '2021-06-25']
    failureRates = [73,91,85,96,55,99] # By percentage terms
    failureTypes = ['None', 'Camera Issue', 'Lighting Issue', 'Night Mode Issue', 'Video Quality Issue', 'Other']
    snPrefix = ['EUHWQ3931-', 'ABC22', 'RRH43144', '283367144', 'teegfhj-22-thgf', 'dgdss']
    batchNums = ['EE1', 'FF2', 'GG3', 'HH4', 'II5']
    testers = ['Zach', 'Ryan', 'Ruohan', 'Nikki', 'Megan', 'Jordy']
    results = ['Pass', 'Fail']
    messages = ['Everything Works', 'Camera is not doing so hot', 'Night mode issue ensued', 'Other issue-unlisted']

    # Populate with 600 dummy entries
    for i in range(6):
        for j in range(100):
            sn = snPrefix[i] + str(j)
            # Generate the date of entry--staggered
            if j % 2 == 0:
                date = sampleDates1[i]
            else:
                date = sampleDates2[i]
            ft = 'Pass' if j < failureRates[i] else 'Fail' # Generate functional test result based on failure rate
            tester = testers[j % 6]
            batchNum = batchNums[j % 5]        
            if ft == 'Pass': # Can get a message + failure type based off of the functional test result
                msg = messages[0]
                fail = failureTypes[0]
            else:
                msg = messages[j % 4]
                fail = failureTypes[i % 3 + 1] if j < 20 else failureTypes[j % 5 + 1] 
            # sn, bn, res, t, msg, fail, d)
            insertEntry(sn, batchNum, ft, tester, msg, fail, date)

# More efficient method to cleara table
def clearTable():
    q = ''' Delete From QAResults '''
    return execute(q)

# %%
execute(''' Select * From QAResults Limit 5''')
# Out:
# [('2833671440',
#   'EE1',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('2833671441',
#   'FF2',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714410',
#   'EE1',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714411',
#   'FF2',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714412',
#   'GG3',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works')]

# %%
execute(''' Select * From QAResults Limit 5 ''')
# Out:
# [('2833671440',
#   'EE1',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('2833671441',
#   'FF2',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714410',
#   'EE1',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714411',
#   'FF2',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714412',
#   'GG3',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works')]

# %%
# Date Queries--directly from SQL DB

# Must obtain an exact match
def getDay(date):
    q = ''' Select * from QAResults where Date = '{}' '''.format(date)
    return execute(q)

# Format: date is passed in as YYYY-MM to be matched against given dates
def getMonth(date):
    q = ''' Select * from QAResults where Substring(Date, 1, 7) = '{}' '''.format(date)
    return execute(q)

# Get all entries for a given year
def getYear(year):
    q = ''' Select * from QAResults where Substring(Date, 1, 4) = '{}' '''.format(year)
    return execute(q)

# Get all entries before a date (inclusive)
def getEntriesBefore(date):
    q = ''' Select * from QAResults where Date < '{}' '''.format(date)
    return execute(q)
    
# Get all entries after a date (inclusive)
def getEntriesAfter(date):
    q = ''' Select * from QAResults where Date >= '{}' '''.format(date)
    return execute(q)

# Get all the entries that fall b/w a specific start and end date
def getEntriesBetween(start, end):
    q = ''' Select * from QAResults where Date <= '{}' and Date >= '{}' '''.format(end, start)
    return execute(q)

# %%
# Testing date framework
def testDateFunctions():
    day = '2021-04-19'
    month = '2021-06'
    year = '2019'
    startDay = '2021-04-19'
    endDay = '2021-06-10'
    print('\n\nGet entries on day:', day)
    display(getDay(day))
    print('\n\nGet entries on month:', month)
    display(getMonth(month))
    print('\n\nGet entries on year:', year)
    display(getYear(year))
    print('\n\nGet entries before day:', day)
    display(getEntriesBefore(day))
    print('\n\nGet entries after day:', day)
    display(getEntriesAfter(day))
    print('\n\nGet entries between:', startDay, 'and', endDay)
    display(getEntriesBetween(startDay, endDay))

testDateFunctions()
# Out:
# Get entries on day: 2021-04-19
# []
# Get entries on month: 2021-06
# []
# Get entries on year: 2019
# []
# Get entries before day: 2021-04-19
# [('2833671440',
#   'EE1',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('2833671441',
#   'FF2',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714410',
#   'EE1',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714411',
#   'FF2',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714412',
#   'GG3',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714413',
#   'HH4',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714414',
#   'II5',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714415',
#   'EE1',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714416',
#   'FF2',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714417',
#   'GG3',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714418',
#   'HH4',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714419',
#   'II5',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('2833671442',
#   'GG3',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714420',
#   'EE1',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714421',
#   'FF2',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714422',
#   'GG3',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714423',
#   'HH4',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714424',
#   'II5',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714425',
#   'EE1',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714426',
#   'FF2',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714427',
#   'GG3',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714428',
#   'HH4',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714429',
#   'II5',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('2833671443',
#   'HH4',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714430',
#   'EE1',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714431',
#   'FF2',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714432',
#   'GG3',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714433',
#   'HH4',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714434',
#   'II5',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714435',
#   'EE1',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714436',
#   'FF2',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714437',
#   'GG3',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714438',
#   'HH4',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714439',
#   'II5',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('2833671444',
#   'II5',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714440',
#   'EE1',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714441',
#   'FF2',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714442',
#   'GG3',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714443',
#   'HH4',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714444',
#   'II5',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714445',
#   'EE1',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714446',
#   'FF2',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714447',
#   'GG3',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714448',
#   'HH4',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714449',
#   'II5',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('2833671445',
#   'EE1',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714450',
#   'EE1',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714451',
#   'FF2',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714452',
#   'GG3',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714453',
#   'HH4',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714454',
#   'II5',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714455',
#   'EE1',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714456',
#   'FF2',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714457',
#   'GG3',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714458',
#   'HH4',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714459',
#   'II5',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('2833671446',
#   'FF2',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714460',
#   'EE1',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714461',
#   'FF2',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714462',
#   'GG3',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714463',
#   'HH4',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714464',
#   'II5',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714465',
#   'EE1',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714466',
#   'FF2',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714467',
#   'GG3',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714468',
#   'HH4',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714469',
#   'II5',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('2833671447',
#   'GG3',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714470',
#   'EE1',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714471',
#   'FF2',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714472',
#   'GG3',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714473',
#   'HH4',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714474',
#   'II5',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714475',
#   'EE1',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714476',
#   'FF2',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714477',
#   'GG3',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714478',
#   'HH4',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714479',
#   'II5',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('2833671448',
#   'HH4',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714480',
#   'EE1',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714481',
#   'FF2',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714482',
#   'GG3',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714483',
#   'HH4',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714484',
#   'II5',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714485',
#   'EE1',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714486',
#   'FF2',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714487',
#   'GG3',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714488',
#   'HH4',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714489',
#   'II5',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('2833671449',
#   'II5',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714490',
#   'EE1',
#   '2021-03-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714491',
#   'FF2',
#   '2021-03-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714492',
#   'GG3',
#   '2021-03-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714493',
#   'HH4',
#   '2021-03-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714494',
#   'II5',
#   '2021-03-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714495',
#   'EE1',
#   '2021-03-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('28336714496',
#   'FF2',
#   '2021-03-15',
#   'Zach',
#   'Fail',
#   'Lighting Issue',
#   'Everything Works'),
#  ('28336714497',
#   'GG3',
#   '2021-03-25',
#   'Ryan',
#   'Fail',
#   'Night Mode Issue',
#   'Camera is not doing so hot'),
#  ('28336714498',
#   'HH4',
#   '2021-03-15',
#   'Ruohan',
#   'Fail',
#   'Video Quality Issue',
#   'Night mode issue ensued'),
#  ('28336714499',
#   'II5',
#   '2021-03-25',
#   'Nikki',
#   'Fail',
#   'Other',
#   'Other issue-unlisted'),
#  ('ABC220', 'EE1', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC221', 'FF2', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2210', 'EE1', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2211', 'FF2', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC2212', 'GG3', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2213', 'HH4', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2214',
#   'II5',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2215', 'EE1', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2216', 'FF2', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2217', 'GG3', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC2218', 'HH4', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2219', 'II5', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC222', 'GG3', '2021-01-15', 'Ruohan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2220',
#   'EE1',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2221', 'FF2', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2222', 'GG3', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2223', 'HH4', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC2224', 'II5', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2225', 'EE1', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2226',
#   'FF2',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2227', 'GG3', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2228', 'HH4', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2229', 'II5', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC223', 'HH4', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2230', 'EE1', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2231', 'FF2', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2232',
#   'GG3',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2233', 'HH4', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2234', 'II5', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2235', 'EE1', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC2236', 'FF2', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2237', 'GG3', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2238',
#   'HH4',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2239', 'II5', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC224', 'II5', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2240', 'EE1', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2241', 'FF2', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC2242', 'GG3', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2243', 'HH4', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2244',
#   'II5',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2245', 'EE1', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2246', 'FF2', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2247', 'GG3', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC2248', 'HH4', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2249', 'II5', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC225', 'EE1', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC2250',
#   'EE1',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2251', 'FF2', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2252', 'GG3', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2253', 'HH4', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC2254', 'II5', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2255', 'EE1', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2256',
#   'FF2',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2257', 'GG3', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2258', 'HH4', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2259', 'II5', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC226', 'FF2', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2260', 'EE1', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2261', 'FF2', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2262',
#   'GG3',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2263', 'HH4', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2264', 'II5', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2265', 'EE1', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC2266', 'FF2', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2267', 'GG3', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2268',
#   'HH4',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2269', 'II5', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC227', 'GG3', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2270', 'EE1', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2271', 'FF2', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC2272', 'GG3', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2273', 'HH4', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2274',
#   'II5',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2275', 'EE1', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2276', 'FF2', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2277', 'GG3', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC2278', 'HH4', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2279', 'II5', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC228', 'HH4', '2021-01-15', 'Ruohan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2280',
#   'EE1',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2281', 'FF2', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2282', 'GG3', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2283', 'HH4', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC2284', 'II5', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2285', 'EE1', '2021-01-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2286',
#   'FF2',
#   '2021-01-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('ABC2287', 'GG3', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2288', 'HH4', '2021-01-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('ABC2289', 'II5', '2021-01-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('ABC229', 'II5', '2021-01-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('ABC2290', 'EE1', '2021-01-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('ABC2291',
#   'FF2',
#   '2021-01-25',
#   'Ryan',
#   'Fail',
#   'Lighting Issue',
#   'Other issue-unlisted'),
#  ('ABC2292',
#   'GG3',
#   '2021-01-15',
#   'Ruohan',
#   'Fail',
#   'Night Mode Issue',
#   'Everything Works'),
#  ('ABC2293',
#   'HH4',
#   '2021-01-25',
#   'Nikki',
#   'Fail',
#   'Video Quality Issue',
#   'Camera is not doing so hot'),
#  ('ABC2294',
#   'II5',
#   '2021-01-15',
#   'Megan',
#   'Fail',
#   'Other',
#   'Night mode issue ensued'),
#  ('ABC2295',
#   'EE1',
#   '2021-01-25',
#   'Jordy',
#   'Fail',
#   'Camera Issue',
#   'Other issue-unlisted'),
#  ('ABC2296',
#   'FF2',
#   '2021-01-15',
#   'Zach',
#   'Fail',
#   'Lighting Issue',
#   'Everything Works'),
#  ('ABC2297',
#   'GG3',
#   '2021-01-25',
#   'Ryan',
#   'Fail',
#   'Night Mode Issue',
#   'Camera is not doing so hot'),
#  ('ABC2298',
#   'HH4',
#   '2021-01-15',
#   'Ruohan',
#   'Fail',
#   'Video Quality Issue',
#   'Night mode issue ensued'),
#  ('ABC2299',
#   'II5',
#   '2021-01-25',
#   'Nikki',
#   'Fail',
#   'Other',
#   'Other issue-unlisted'),
#  ('EUHWQ3931-0',
#   'EE1',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-1',
#   'FF2',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-10',
#   'EE1',
#   '2020-12-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-11',
#   'FF2',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-12',
#   'GG3',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-13',
#   'HH4',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-14',
#   'II5',
#   '2020-12-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-15',
#   'EE1',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-16',
#   'FF2',
#   '2020-12-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-17',
#   'GG3',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-18',
#   'HH4',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-19',
#   'II5',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-2',
#   'GG3',
#   '2020-12-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-20',
#   'EE1',
#   '2020-12-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-21',
#   'FF2',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-22',
#   'GG3',
#   '2020-12-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-23',
#   'HH4',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-24',
#   'II5',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-25',
#   'EE1',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-26',
#   'FF2',
#   '2020-12-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-27',
#   'GG3',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-28',
#   'HH4',
#   '2020-12-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-29',
#   'II5',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-3',
#   'HH4',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-30',
#   'EE1',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-31',
#   'FF2',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-32',
#   'GG3',
#   '2020-12-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-33',
#   'HH4',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-34',
#   'II5',
#   '2020-12-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-35',
#   'EE1',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-36',
#   'FF2',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-37',
#   'GG3',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-38',
#   'HH4',
#   '2020-12-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-39',
#   'II5',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-4',
#   'II5',
#   '2020-12-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-40',
#   'EE1',
#   '2020-12-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-41',
#   'FF2',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-42',
#   'GG3',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-43',
#   'HH4',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-44',
#   'II5',
#   '2020-12-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-45',
#   'EE1',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-46',
#   'FF2',
#   '2020-12-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-47',
#   'GG3',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-48',
#   'HH4',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-49',
#   'II5',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-5',
#   'EE1',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-50',
#   'EE1',
#   '2020-12-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-51',
#   'FF2',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-52',
#   'GG3',
#   '2020-12-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-53',
#   'HH4',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-54',
#   'II5',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-55',
#   'EE1',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-56',
#   'FF2',
#   '2020-12-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-57',
#   'GG3',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-58',
#   'HH4',
#   '2020-12-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-59',
#   'II5',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-6',
#   'FF2',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-60',
#   'EE1',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-61',
#   'FF2',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-62',
#   'GG3',
#   '2020-12-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-63',
#   'HH4',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-64',
#   'II5',
#   '2020-12-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-65',
#   'EE1',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-66',
#   'FF2',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-67',
#   'GG3',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-68',
#   'HH4',
#   '2020-12-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-69',
#   'II5',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-7',
#   'GG3',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-70',
#   'EE1',
#   '2020-12-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-71',
#   'FF2',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-72',
#   'GG3',
#   '2020-12-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-73',
#   'HH4',
#   '2020-12-25',
#   'Ryan',
#   'Fail',
#   'Video Quality Issue',
#   'Camera is not doing so hot'),
#  ('EUHWQ3931-74',
#   'II5',
#   '2020-12-15',
#   'Ruohan',
#   'Fail',
#   'Other',
#   'Night mode issue ensued'),
#  ('EUHWQ3931-75',
#   'EE1',
#   '2020-12-25',
#   'Nikki',
#   'Fail',
#   'Camera Issue',
#   'Other issue-unlisted'),
#  ('EUHWQ3931-76',
#   'FF2',
#   '2020-12-15',
#   'Megan',
#   'Fail',
#   'Lighting Issue',
#   'Everything Works'),
#  ('EUHWQ3931-77',
#   'GG3',
#   '2020-12-25',
#   'Jordy',
#   'Fail',
#   'Night Mode Issue',
#   'Camera is not doing so hot'),
#  ('EUHWQ3931-78',
#   'HH4',
#   '2020-12-15',
#   'Zach',
#   'Fail',
#   'Video Quality Issue',
#   'Night mode issue ensued'),
#  ('EUHWQ3931-79',
#   'II5',
#   '2020-12-25',
#   'Ryan',
#   'Fail',
#   'Other',
#   'Other issue-unlisted'),
#  ('EUHWQ3931-8',
#   'HH4',
#   '2020-12-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-80',
#   'EE1',
#   '2020-12-15',
#   'Ruohan',
#   'Fail',
#   'Camera Issue',
#   'Everything Works'),
#  ('EUHWQ3931-81',
#   'FF2',
#   '2020-12-25',
#   'Nikki',
#   'Fail',
#   'Lighting Issue',
#   'Camera is not doing so hot'),
#  ('EUHWQ3931-82',
#   'GG3',
#   '2020-12-15',
#   'Megan',
#   'Fail',
#   'Night Mode Issue',
#   'Night mode issue ensued'),
#  ('EUHWQ3931-83',
#   'HH4',
#   '2020-12-25',
#   'Jordy',
#   'Fail',
#   'Video Quality Issue',
#   'Other issue-unlisted'),
#  ('EUHWQ3931-84',
#   'II5',
#   '2020-12-15',
#   'Zach',
#   'Fail',
#   'Other',
#   'Everything Works'),
#  ('EUHWQ3931-85',
#   'EE1',
#   '2020-12-25',
#   'Ryan',
#   'Fail',
#   'Camera Issue',
#   'Camera is not doing so hot'),
#  ('EUHWQ3931-86',
#   'FF2',
#   '2020-12-15',
#   'Ruohan',
#   'Fail',
#   'Lighting Issue',
#   'Night mode issue ensued'),
#  ('EUHWQ3931-87',
#   'GG3',
#   '2020-12-25',
#   'Nikki',
#   'Fail',
#   'Night Mode Issue',
#   'Other issue-unlisted'),
#  ('EUHWQ3931-88',
#   'HH4',
#   '2020-12-15',
#   'Megan',
#   'Fail',
#   'Video Quality Issue',
#   'Everything Works'),
#  ('EUHWQ3931-89',
#   'II5',
#   '2020-12-25',
#   'Jordy',
#   'Fail',
#   'Other',
#   'Camera is not doing so hot'),
#  ('EUHWQ3931-9',
#   'II5',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('EUHWQ3931-90',
#   'EE1',
#   '2020-12-15',
#   'Zach',
#   'Fail',
#   'Camera Issue',
#   'Night mode issue ensued'),
#  ('EUHWQ3931-91',
#   'FF2',
#   '2020-12-25',
#   'Ryan',
#   'Fail',
#   'Lighting Issue',
#   'Other issue-unlisted'),
#  ('EUHWQ3931-92',
#   'GG3',
#   '2020-12-15',
#   'Ruohan',
#   'Fail',
#   'Night Mode Issue',
#   'Everything Works'),
#  ('EUHWQ3931-93',
#   'HH4',
#   '2020-12-25',
#   'Nikki',
#   'Fail',
#   'Video Quality Issue',
#   'Camera is not doing so hot'),
#  ('EUHWQ3931-94',
#   'II5',
#   '2020-12-15',
#   'Megan',
#   'Fail',
#   'Other',
#   'Night mode issue ensued'),
#  ('EUHWQ3931-95',
#   'EE1',
#   '2020-12-25',
#   'Jordy',
#   'Fail',
#   'Camera Issue',
#   'Other issue-unlisted'),
#  ('EUHWQ3931-96',
#   'FF2',
#   '2020-12-15',
#   'Zach',
#   'Fail',
#   'Lighting Issue',
#   'Everything Works'),
#  ('EUHWQ3931-97',
#   'GG3',
#   '2020-12-25',
#   'Ryan',
#   'Fail',
#   'Night Mode Issue',
#   'Camera is not doing so hot'),
#  ('EUHWQ3931-98',
#   'HH4',
#   '2020-12-15',
#   'Ruohan',
#   'Fail',
#   'Video Quality Issue',
#   'Night mode issue ensued'),
#  ('EUHWQ3931-99',
#   'II5',
#   '2020-12-25',
#   'Nikki',
#   'Fail',
#   'Other',
#   'Other issue-unlisted'),
#  ('RRH431440',
#   'EE1',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH431441',
#   'FF2',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314410',
#   'EE1',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314411',
#   'FF2',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314412',
#   'GG3',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314413',
#   'HH4',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314414',
#   'II5',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314415',
#   'EE1',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314416',
#   'FF2',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314417',
#   'GG3',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314418',
#   'HH4',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314419',
#   'II5',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH431442',
#   'GG3',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314420',
#   'EE1',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314421',
#   'FF2',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314422',
#   'GG3',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314423',
#   'HH4',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314424',
#   'II5',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314425',
#   'EE1',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314426',
#   'FF2',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314427',
#   'GG3',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314428',
#   'HH4',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314429',
#   'II5',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH431443',
#   'HH4',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314430',
#   'EE1',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314431',
#   'FF2',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314432',
#   'GG3',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314433',
#   'HH4',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314434',
#   'II5',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314435',
#   'EE1',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314436',
#   'FF2',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314437',
#   'GG3',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314438',
#   'HH4',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314439',
#   'II5',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH431444',
#   'II5',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314440',
#   'EE1',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314441',
#   'FF2',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314442',
#   'GG3',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314443',
#   'HH4',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314444',
#   'II5',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314445',
#   'EE1',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314446',
#   'FF2',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314447',
#   'GG3',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314448',
#   'HH4',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314449',
#   'II5',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH431445',
#   'EE1',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314450',
#   'EE1',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314451',
#   'FF2',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314452',
#   'GG3',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314453',
#   'HH4',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314454',
#   'II5',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314455',
#   'EE1',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314456',
#   'FF2',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314457',
#   'GG3',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314458',
#   'HH4',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314459',
#   'II5',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH431446',
#   'FF2',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314460',
#   'EE1',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314461',
#   'FF2',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314462',
#   'GG3',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314463',
#   'HH4',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314464',
#   'II5',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314465',
#   'EE1',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314466',
#   'FF2',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314467',
#   'GG3',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314468',
#   'HH4',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314469',
#   'II5',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH431447',
#   'GG3',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314470',
#   'EE1',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314471',
#   'FF2',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314472',
#   'GG3',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314473',
#   'HH4',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314474',
#   'II5',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314475',
#   'EE1',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314476',
#   'FF2',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314477',
#   'GG3',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314478',
#   'HH4',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314479',
#   'II5',
#   '2020-12-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH431448',
#   'HH4',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314480',
#   'EE1',
#   '2021-02-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314481',
#   'FF2',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314482',
#   'GG3',
#   '2021-02-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314483',
#   'HH4',
#   '2020-12-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314484',
#   'II5',
#   '2021-02-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314485',
#   'EE1',
#   '2020-12-25',
#   'Ryan',
#   'Fail',
#   'Camera Issue',
#   'Camera is not doing so hot'),
#  ('RRH4314486',
#   'FF2',
#   '2021-02-15',
#   'Ruohan',
#   'Fail',
#   'Lighting Issue',
#   'Night mode issue ensued'),
#  ('RRH4314487',
#   'GG3',
#   '2020-12-25',
#   'Nikki',
#   'Fail',
#   'Night Mode Issue',
#   'Other issue-unlisted'),
#  ('RRH4314488',
#   'HH4',
#   '2021-02-15',
#   'Megan',
#   'Fail',
#   'Video Quality Issue',
#   'Everything Works'),
#  ('RRH4314489',
#   'II5',
#   '2020-12-25',
#   'Jordy',
#   'Fail',
#   'Other',
#   'Camera is not doing so hot'),
#  ('RRH431449',
#   'II5',
#   '2020-12-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('RRH4314490',
#   'EE1',
#   '2021-02-15',
#   'Zach',
#   'Fail',
#   'Camera Issue',
#   'Night mode issue ensued'),
#  ('RRH4314491',
#   'FF2',
#   '2020-12-25',
#   'Ryan',
#   'Fail',
#   'Lighting Issue',
#   'Other issue-unlisted'),
#  ('RRH4314492',
#   'GG3',
#   '2021-02-15',
#   'Ruohan',
#   'Fail',
#   'Night Mode Issue',
#   'Everything Works'),
#  ('RRH4314493',
#   'HH4',
#   '2020-12-25',
#   'Nikki',
#   'Fail',
#   'Video Quality Issue',
#   'Camera is not doing so hot'),
#  ('RRH4314494',
#   'II5',
#   '2021-02-15',
#   'Megan',
#   'Fail',
#   'Other',
#   'Night mode issue ensued'),
#  ('RRH4314495',
#   'EE1',
#   '2020-12-25',
#   'Jordy',
#   'Fail',
#   'Camera Issue',
#   'Other issue-unlisted'),
#  ('RRH4314496',
#   'FF2',
#   '2021-02-15',
#   'Zach',
#   'Fail',
#   'Lighting Issue',
#   'Everything Works'),
#  ('RRH4314497',
#   'GG3',
#   '2020-12-25',
#   'Ryan',
#   'Fail',
#   'Night Mode Issue',
#   'Camera is not doing so hot'),
#  ('RRH4314498',
#   'HH4',
#   '2021-02-15',
#   'Ruohan',
#   'Fail',
#   'Video Quality Issue',
#   'Night mode issue ensued'),
#  ('RRH4314499',
#   'II5',
#   '2020-12-25',
#   'Nikki',
#   'Fail',
#   'Other',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf0',
#   'EE1',
#   '2021-04-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf10',
#   'EE1',
#   '2021-04-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf12',
#   'GG3',
#   '2021-04-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf14',
#   'II5',
#   '2021-04-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf16',
#   'FF2',
#   '2021-04-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf18',
#   'HH4',
#   '2021-04-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf2',
#   'GG3',
#   '2021-04-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf20',
#   'EE1',
#   '2021-04-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf22',
#   'GG3',
#   '2021-04-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf24',
#   'II5',
#   '2021-04-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf26',
#   'FF2',
#   '2021-04-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf28',
#   'HH4',
#   '2021-04-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf30',
#   'EE1',
#   '2021-04-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf32',
#   'GG3',
#   '2021-04-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf34',
#   'II5',
#   '2021-04-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf36',
#   'FF2',
#   '2021-04-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf38',
#   'HH4',
#   '2021-04-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf4',
#   'II5',
#   '2021-04-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf40',
#   'EE1',
#   '2021-04-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf42',
#   'GG3',
#   '2021-04-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf44',
#   'II5',
#   '2021-04-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf46',
#   'FF2',
#   '2021-04-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf48',
#   'HH4',
#   '2021-04-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf50',
#   'EE1',
#   '2021-04-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf52',
#   'GG3',
#   '2021-04-15',
#   'Megan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf54',
#   'II5',
#   '2021-04-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf56',
#   'FF2',
#   '2021-04-15',
#   'Ruohan',
#   'Fail',
#   'Lighting Issue',
#   'Everything Works'),
#  ('teegfhj-22-thgf58',
#   'HH4',
#   '2021-04-15',
#   'Megan',
#   'Fail',
#   'Video Quality Issue',
#   'Night mode issue ensued'),
#  ('teegfhj-22-thgf6',
#   'FF2',
#   '2021-04-15',
#   'Zach',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf60',
#   'EE1',
#   '2021-04-15',
#   'Zach',
#   'Fail',
#   'Camera Issue',
#   'Everything Works'),
#  ('teegfhj-22-thgf62',
#   'GG3',
#   '2021-04-15',
#   'Ruohan',
#   'Fail',
#   'Night Mode Issue',
#   'Night mode issue ensued'),
#  ('teegfhj-22-thgf64',
#   'II5',
#   '2021-04-15',
#   'Megan',
#   'Fail',
#   'Other',
#   'Everything Works'),
#  ('teegfhj-22-thgf66',
#   'FF2',
#   '2021-04-15',
#   'Zach',
#   'Fail',
#   'Lighting Issue',
#   'Night mode issue ensued'),
#  ('teegfhj-22-thgf68',
#   'HH4',
#   '2021-04-15',
#   'Ruohan',
#   'Fail',
#   'Video Quality Issue',
#   'Everything Works'),
#  ('teegfhj-22-thgf70',
#   'EE1',
#   '2021-04-15',
#   'Megan',
#   'Fail',
#   'Camera Issue',
#   'Night mode issue ensued'),
#  ('teegfhj-22-thgf72',
#   'GG3',
#   '2021-04-15',
#   'Zach',
#   'Fail',
#   'Night Mode Issue',
#   'Everything Works'),
#  ('teegfhj-22-thgf74',
#   'II5',
#   '2021-04-15',
#   'Ruohan',
#   'Fail',
#   'Other',
#   'Night mode issue ensued'),
#  ('teegfhj-22-thgf76',
#   'FF2',
#   '2021-04-15',
#   'Megan',
#   'Fail',
#   'Lighting Issue',
#   'Everything Works'),
#  ('teegfhj-22-thgf78',
#   'HH4',
#   '2021-04-15',
#   'Zach',
#   'Fail',
#   'Video Quality Issue',
#   'Night mode issue ensued'),
#  ('teegfhj-22-thgf8',
#   'HH4',
#   '2021-04-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf80',
#   'EE1',
#   '2021-04-15',
#   'Ruohan',
#   'Fail',
#   'Camera Issue',
#   'Everything Works'),
#  ('teegfhj-22-thgf82',
#   'GG3',
#   '2021-04-15',
#   'Megan',
#   'Fail',
#   'Night Mode Issue',
#   'Night mode issue ensued'),
#  ('teegfhj-22-thgf84',
#   'II5',
#   '2021-04-15',
#   'Zach',
#   'Fail',
#   'Other',
#   'Everything Works'),
#  ('teegfhj-22-thgf86',
#   'FF2',
#   '2021-04-15',
#   'Ruohan',
#   'Fail',
#   'Lighting Issue',
#   'Night mode issue ensued'),
#  ('teegfhj-22-thgf88',
#   'HH4',
#   '2021-04-15',
#   'Megan',
#   'Fail',
#   'Video Quality Issue',
#   'Everything Works'),
#  ('teegfhj-22-thgf90',
#   'EE1',
#   '2021-04-15',
#   'Zach',
#   'Fail',
#   'Camera Issue',
#   'Night mode issue ensued'),
#  ('teegfhj-22-thgf92',
#   'GG3',
#   '2021-04-15',
#   'Ruohan',
#   'Fail',
#   'Night Mode Issue',
#   'Everything Works'),
#  ('teegfhj-22-thgf94',
#   'II5',
#   '2021-04-15',
#   'Megan',
#   'Fail',
#   'Other',
#   'Night mode issue ensued'),
#  ('teegfhj-22-thgf96',
#   'FF2',
#   '2021-04-15',
#   'Zach',
#   'Fail',
#   'Lighting Issue',
#   'Everything Works'),
#  ('teegfhj-22-thgf98',
#   'HH4',
#   '2021-04-15',
#   'Ruohan',
#   'Fail',
#   'Video Quality Issue',
#   'Night mode issue ensued')]
# Get entries after day: 2021-04-19
# [('dgdss0', 'EE1', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss1', 'FF2', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss10', 'EE1', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss11', 'FF2', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss12', 'GG3', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss13', 'HH4', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss14',
#   'II5',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss15', 'EE1', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss16', 'FF2', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss17', 'GG3', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss18', 'HH4', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss19', 'II5', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss2', 'GG3', '2021-05-15', 'Ruohan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss20',
#   'EE1',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss21', 'FF2', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss22', 'GG3', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss23', 'HH4', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss24', 'II5', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss25', 'EE1', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss26',
#   'FF2',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss27', 'GG3', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss28', 'HH4', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss29', 'II5', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss3', 'HH4', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss30', 'EE1', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss31', 'FF2', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss32',
#   'GG3',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss33', 'HH4', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss34', 'II5', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss35', 'EE1', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss36', 'FF2', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss37', 'GG3', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss38',
#   'HH4',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss39', 'II5', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss4', 'II5', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss40', 'EE1', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss41', 'FF2', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss42', 'GG3', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss43', 'HH4', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss44',
#   'II5',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss45', 'EE1', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss46', 'FF2', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss47', 'GG3', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss48', 'HH4', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss49', 'II5', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss5', 'EE1', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss50',
#   'EE1',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss51', 'FF2', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss52', 'GG3', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss53', 'HH4', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss54', 'II5', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss55', 'EE1', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss56',
#   'FF2',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss57', 'GG3', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss58', 'HH4', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss59', 'II5', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss6', 'FF2', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
# ...
#  ('teegfhj-22-thgf65',
#   'EE1',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Camera Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf67',
#   'GG3',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Night Mode Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf69',
#   'II5',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Other',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf7',
#   'GG3',
#   '2021-04-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf71',
#   'FF2',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Lighting Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf73',
#   'HH4',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Video Quality Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf75',
#   'EE1',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Camera Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf77',
#   'GG3',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Night Mode Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf79',
#   'II5',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Other',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf81',
#   'FF2',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Lighting Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf83',
#   'HH4',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Video Quality Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf85',
#   'EE1',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Camera Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf87',
#   'GG3',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Night Mode Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf89',
#   'II5',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Other',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf9',
#   'II5',
#   '2021-04-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf91',
#   'FF2',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Lighting Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf93',
#   'HH4',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Video Quality Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf95',
#   'EE1',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Camera Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf97',
#   'GG3',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Night Mode Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf99',
#   'II5',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Other',
#   'Other issue-unlisted')]
# Get entries between: 2021-04-19 and 2021-06-10
# [('dgdss0', 'EE1', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss1', 'FF2', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss10', 'EE1', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss11', 'FF2', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss12', 'GG3', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss13', 'HH4', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss14',
#   'II5',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss15', 'EE1', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss16', 'FF2', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss17', 'GG3', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss18', 'HH4', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss19', 'II5', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss2', 'GG3', '2021-05-15', 'Ruohan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss20',
#   'EE1',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss21', 'FF2', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss22', 'GG3', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss23', 'HH4', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss24', 'II5', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss25', 'EE1', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss26',
#   'FF2',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss27', 'GG3', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss28', 'HH4', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss29', 'II5', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss3', 'HH4', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss30', 'EE1', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss31', 'FF2', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss32',
#   'GG3',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss33', 'HH4', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss34', 'II5', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss35', 'EE1', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss36', 'FF2', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss37', 'GG3', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss38',
#   'HH4',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss39', 'II5', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss4', 'II5', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss40', 'EE1', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss41', 'FF2', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss42', 'GG3', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss43', 'HH4', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss44',
#   'II5',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss45', 'EE1', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss46', 'FF2', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss47', 'GG3', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss48', 'HH4', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss49', 'II5', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss5', 'EE1', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss50',
#   'EE1',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss51', 'FF2', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss52', 'GG3', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss53', 'HH4', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss54', 'II5', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss55', 'EE1', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss56',
#   'FF2',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss57', 'GG3', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss58', 'HH4', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss59', 'II5', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss6', 'FF2', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss60', 'EE1', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss61', 'FF2', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss62',
#   'GG3',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss63', 'HH4', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss64', 'II5', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss65', 'EE1', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss66', 'FF2', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss67', 'GG3', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss68',
#   'HH4',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss69', 'II5', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss7', 'GG3', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss70', 'EE1', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss71', 'FF2', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss72', 'GG3', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss73', 'HH4', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss74',
#   'II5',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss75', 'EE1', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss76', 'FF2', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss77', 'GG3', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss78', 'HH4', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss79', 'II5', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss8', 'HH4', '2021-05-15', 'Ruohan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss80',
#   'EE1',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss81', 'FF2', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss82', 'GG3', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss83', 'HH4', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss84', 'II5', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss85', 'EE1', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss86',
#   'FF2',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss87', 'GG3', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss88', 'HH4', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss89', 'II5', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss9', 'II5', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss90', 'EE1', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss91', 'FF2', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss92',
#   'GG3',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss93', 'HH4', '2021-05-25', 'Nikki', 'Pass', 'None', 'Everything Works'),
#  ('dgdss94', 'II5', '2021-05-15', 'Megan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss95', 'EE1', '2021-05-25', 'Jordy', 'Pass', 'None', 'Everything Works'),
#  ('dgdss96', 'FF2', '2021-05-15', 'Zach', 'Pass', 'None', 'Everything Works'),
#  ('dgdss97', 'GG3', '2021-05-25', 'Ryan', 'Pass', 'None', 'Everything Works'),
#  ('dgdss98',
#   'HH4',
#   '2021-05-15',
#   'Ruohan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('dgdss99',
#   'II5',
#   '2021-05-25',
#   'Nikki',
#   'Fail',
#   'Other',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf1',
#   'FF2',
#   '2021-04-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf11',
#   'FF2',
#   '2021-04-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf13',
#   'HH4',
#   '2021-04-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf15',
#   'EE1',
#   '2021-04-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf17',
#   'GG3',
#   '2021-04-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf19',
#   'II5',
#   '2021-04-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf21',
#   'FF2',
#   '2021-04-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf23',
#   'HH4',
#   '2021-04-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf25',
#   'EE1',
#   '2021-04-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf27',
#   'GG3',
#   '2021-04-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf29',
#   'II5',
#   '2021-04-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf3',
#   'HH4',
#   '2021-04-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf31',
#   'FF2',
#   '2021-04-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf33',
#   'HH4',
#   '2021-04-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf35',
#   'EE1',
#   '2021-04-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf37',
#   'GG3',
#   '2021-04-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf39',
#   'II5',
#   '2021-04-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf41',
#   'FF2',
#   '2021-04-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf43',
#   'HH4',
#   '2021-04-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf45',
#   'EE1',
#   '2021-04-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf47',
#   'GG3',
#   '2021-04-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf49',
#   'II5',
#   '2021-04-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf5',
#   'EE1',
#   '2021-04-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf51',
#   'FF2',
#   '2021-04-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf53',
#   'HH4',
#   '2021-04-25',
#   'Jordy',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf55',
#   'EE1',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Camera Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf57',
#   'GG3',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Night Mode Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf59',
#   'II5',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Other',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf61',
#   'FF2',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Lighting Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf63',
#   'HH4',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Video Quality Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf65',
#   'EE1',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Camera Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf67',
#   'GG3',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Night Mode Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf69',
#   'II5',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Other',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf7',
#   'GG3',
#   '2021-04-25',
#   'Ryan',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf71',
#   'FF2',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Lighting Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf73',
#   'HH4',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Video Quality Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf75',
#   'EE1',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Camera Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf77',
#   'GG3',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Night Mode Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf79',
#   'II5',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Other',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf81',
#   'FF2',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Lighting Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf83',
#   'HH4',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Video Quality Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf85',
#   'EE1',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Camera Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf87',
#   'GG3',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Night Mode Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf89',
#   'II5',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Other',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf9',
#   'II5',
#   '2021-04-25',
#   'Nikki',
#   'Pass',
#   'None',
#   'Everything Works'),
#  ('teegfhj-22-thgf91',
#   'FF2',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Lighting Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf93',
#   'HH4',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Video Quality Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf95',
#   'EE1',
#   '2021-04-25',
#   'Jordy',
#   'Fail',
#   'Camera Issue',
#   'Other issue-unlisted'),
#  ('teegfhj-22-thgf97',
#   'GG3',
#   '2021-04-25',
#   'Ryan',
#   'Fail',
#   'Night Mode Issue',
#   'Camera is not doing so hot'),
#  ('teegfhj-22-thgf99',
#   'II5',
#   '2021-04-25',
#   'Nikki',
#   'Fail',
#   'Other',
#   'Other issue-unlisted')]

# %%
df = convertToDF('QAResults')
df.head(10) # Display the first 10 entries
# Out:
#   SerialNumber BatchNumber        Date  Tester FunctionalTest FailureType  \
# 0   2833671440         EE1  2021-03-15    Zach           Pass        None
# 1   2833671441         FF2  2021-03-25    Ryan           Pass        None
# 2  28336714410         EE1  2021-03-15   Megan           Pass        None
# 3  28336714411         FF2  2021-03-25   Jordy           Pass        None
# 4  28336714412         GG3  2021-03-15    Zach           Pass        None
# 5  28336714413         HH4  2021-03-25    Ryan           Pass        None
# 6  28336714414         II5  2021-03-15  Ruohan           Pass        None
# 7  28336714415         EE1  2021-03-25   Nikki           Pass        None
# 8  28336714416         FF2  2021-03-15   Megan           Pass        None
# 9  28336714417         GG3  2021-03-25   Jordy           Pass        None
#
#          LogMessage
# 0  Everything Works
# 1  Everything Works
# 2  Everything Works
# 3  Everything Works
# 4  Everything Works
# 5  Everything Works
# 6  Everything Works
# 7  Everything Works
# 8  Everything Works
# 9  Everything Works

# %%
# Starting with trend visualization
display(df[df['FunctionalTest'] == 'Pass'].head()) # Show entries that pass
print('Passrate:' , sum((df['FunctionalTest'] == 'Pass'))/len(df))
# Out:
#   SerialNumber BatchNumber        Date Tester FunctionalTest FailureType  \
# 0   2833671440         EE1  2021-03-15   Zach           Pass        None
# 1   2833671441         FF2  2021-03-25   Ryan           Pass        None
# 2  28336714410         EE1  2021-03-15  Megan           Pass        None
# 3  28336714411         FF2  2021-03-25  Jordy           Pass        None
# 4  28336714412         GG3  2021-03-15   Zach           Pass        None
#
#          LogMessage
# 0  Everything Works
# 1  Everything Works
# 2  Everything Works
# 3  Everything Works
# 4  Everything Works
# Passrate: 0.8316666666666667

# %%
# Working with visualizations
byResult = df['FunctionalTest'].value_counts()
display(byResult)
#display(byResult)
plt.figure(figsize = (10, 5))
sns.barplot(x = byResult.index, y = byResult)
plt.title('Functional Test Results')
plt.xlabel('Pass vs. Fail quantities')
plt.ylabel('Functional Test--Pass/Fail');
#sns.barplot(y = 'FunctionalTest', data = df)
# Out:
# Pass    499
# Fail    101
# Name: FunctionalTest, dtype: int64

# %%
sns.set_style('darkgrid')
# Methods for trend visualization

# Raw counts for functional test results
def compareFunctionalTests(df, start = None, end = None):
    byResult = df['FunctionalTest'].value_counts()
    plt.figure(figsize = (10, 6))
    plt.legend(['Pass', 'Fail'])
    #plt.bar(x = byResult.index, height = byResult)
    plot = sns.barplot(x = byResult.index, y = byResult)
    if start == None and end == None:
        title = 'Functional Test Results' 
    elif start == None:
        title = 'Functional Test Results Until ' + str(end)
    elif end == None:
        title = 'Functional Test Results From ' + str(start) + ' To Present'
    else:
        title = 'Functional Test Results From ' + start + ' To ' + end
    plot.set(xlabel = 'Pass vs. Fail', ylabel = 'Functional Test-Raw Counts', title = title)
    return plot

# Get the relative counts
def relativeFunctionalTests(df, start = None, end = None):
    relativeRates = df['FunctionalTest'].value_counts(normalize = True) * 100
    plt.figure(figsize = (10, 6))
    plot = sns.barplot(x = relativeRates.index, y = relativeRates)
    #plot.legend(['Pass', 'Fail'])
    if start == None and end == None:
        title = 'Functional Test Results By Percentage' 
    elif start == None:
        title = 'Functional Test Results By Perecentage Until ' + str(end)
    elif end == None:
        title = 'Functional Test Results By Percentage: From ' + str(start) + ' To Present'
    else:
        title = 'Functional Test Results From ' + start + ' To ' + end
    plot.set(xlabel = 'Pass vs. Fail', ylabel = 'Percentage (%) Pass/Fail', title = title)
    return plot

# Failure rates by catgory (% of ALL entries that fall under each bucket)
def failureVisual(df, start = None, end = None):
    origSize = len(df) # Get the number of total entries
    byFailure = df['FailureType'].value_counts(normalize = True) * 100 # Get percentage of failure rates
    byFailure = byFailure.drop(labels = ['None']) # Don't need to retain the non-failure options
    plt.figure(figsize = (10, 6))
    plot = sns.barplot(x = byFailure.index, y = byFailure)
    if start == None and end == None:
        title = 'Most Common Failure Types' 
    elif start == None:
        title = 'Common Failure Types Until ' + str(end)
    elif end == None:
        title = 'Most Common Failure Types: From ' + str(start) + ' To Present'
    else:
        title = 'Most Common Failure Types: ' + start + ' To ' + end
    plot.set(xlabel = 'Failure Category', ylabel = 'Percentage of Failure Type (%)', title = title)
    labels = ['Camera Issue', 'Lighting Issue', 'Night Mode Issue', 'Video Quality Issue', 'Other']
    #plt.legend(labels = labels, loc = 1) # Include a legend
    plt.show(plot)
    return plot

# Visualize the failure rate over time by time segments broken down by segment (days/weeks/months/years) + segLength
# Have the option to choose whether to have continuous over time or with NaN data show up as gaps
def failureOverTime(df, start, end, segType = 'day', x = 1, cont = True):
    startDate = dt.datetime.strptime(start, '%Y-%m-%d') # Get Datetime version
    endDate = dt.datetime.strptime(end, '%Y-%m-%d') # Get datetime version of the end
    failureRates = []
    while startDate <= endDate:
        if segType == 'day':
            tempEnd = startDate + pd.offsets.DateOffset(days = x) # Get the end date for end of a time chunk
        elif segType == 'month':
            tempEnd = startDate + pd.offsets.DateOffset(months = x)
        elif segType == 'week':
            tempEnd = startDate + pd.offsets.DateOffset(weeks = x)
        elif segType == 'year':
            tempEnd = startDate + pd.offsets.DateOffset(years = x)
        strStart = startDate.strftime('%Y-%m-%d') # Convert to the string version for START
        strEnd = tempEnd.strftime('%Y-%m-%d') # String vesion of END
        relEntries = df[(df['Date'] >= strStart) & (df['Date'] < strEnd)] # Keep only dates w/in a specific range
        if len(relEntries) != 0: # So long as some tests were conducted in the timeframe
            passRate = relEntries['FunctionalTest'].value_counts(normalize = True)['Pass'] # Find the Pass rate
            failRate = (1 - passRate) * 100 # Add in the failure rate
            failureRates.append([startDate.date(), failRate])
        else: # Case where no entries were used
            failureRates.append([startDate.date(), np.nan])
        startDate = tempEnd
    
        
    failDF = pd.DataFrame(failureRates, columns = ['Start Date', 'Failure Rate'])
    #display(failDF)
    plt.figure(figsize = (10, 6))
    plt.xticks(rotation = 45)
    if cont:
        plot = sns.lineplot(data = failDF, x = 'Start Date', y = 'Failure Rate') # Continuous plot
    else:
        plot = sns.pointplot(data = failDF, x = 'Start Date', y = 'Failure Rate') # Discrete points that are "connected"
    plot.set(xlabel = 'Start Date', ylabel = 'Failure Rate (%)', title = 'Failure Rate From ' + start + ' To ' + end);
    
    return plot;

# %%
# Testing basic functionality of graphing
compareFunctionalTests(df);
plt.savefig('funcTests.png');
relativeFunctionalTests(df);
plt.savefig('funcTestsRelative.png');
failureVisual(df);
plt.savefig('failureType.png');

# %%
# Testing the failure over time function
failureOverTime(df, '2021-03-10', getDate(), 'day', 30)
failureOverTime(df, '2021-03-10', getDate(), 'day', 30, False)
failureOverTime(df, '2021-03-10', getDate(), 'day', 10)
failureOverTime(df, '2021-03-10', getDate(), 'month', 1)
failureOverTime(df, '2021-03-10', getDate(), 'week', 1)
# Out:
# <AxesSubplot:title={'center':'Failure Rate From 2021-03-10 To 2021-06-18'}, xlabel='Start Date', ylabel='Failure Rate (%)'>

# %%
# Applying date filters to DF directly (instead of going through the SQL DB)
def beforeEntries(end):
    return df[df['Date'] <= end]
def afterEntries(start):
    return df[df['Date'] >= start]
def betweenEntries(start, end):
    return df[(df['Date'] >= start) & (df['Date'] <= end)]

# %%
# Adding data labels: https://medium.com/swlh/quick-guide-to-labelling-data-for-common-seaborn-plots-736e10bf14a9

# Visualization with time constraint

# Create a graph visual over the past X days/weeks/months/years--choose the visual type
# Potential graph types: rawFail, relFail, failTypes
def visualFailTime(x, segType, graphType):
    if segType == 'day':
        tempEnd = dt.datetime.today() - pd.offsets.DateOffset(days = x) # Get the end date for end of a time chunk
    elif segType == 'month':
        tempEnd = dt.datetime.today()  - pd.offsets.DateOffset(months = x)
    elif segType == 'week':
        tempEnd = dt.datetime.today()  - pd.offsets.DateOffset(weeks = x)
    elif segType == 'year':
        tempEnd = dt.datetime.today()  - pd.offsets.DateOffset(years = x)
    tempEnd = tempEnd.strftime('%Y-%m-%d') 
    #print(tempEnd)
    relEntries = df[df['Date'] > tempEnd] # Only preserve the entries that are from relevant date onward
    #display(relEntries)
    if graphType == 'rawFail': 
        return compareFunctionalTests(relEntries, tempEnd)
    if graphType == 'relFail': # Generate the proportion of failures (relative)
        return relativeFunctionalTests(relEntries, tempEnd)
    if graphType == 'failTypes':
        return failureVisual(relEntries, tempEnd)

# Create a visual based off of the starting + ending date
def visualBetweenTime(start, end, graphType):
    relEntries = betweenEntries(start, end)
    if graphType == 'rawFail': 
        return compareFunctionalTests(relEntries, start, end)
    if graphType == 'relFail': # Generate the proportion of failures (relative)
        return relativeFunctionalTests(relEntries, start, end)
    if graphType == 'failTypes':
        return failureVisual(relEntries, start, end)

# %%
# Testing the Visual Generation
visualFailTime(30, 'day', 'rawFail');
visualFailTime(10, 'week', 'relFail');
visualFailTime(4, 'month', 'failTypes');

# %% [markdown]
# ### Everything beneath is outdated

# %%
# client = boto3.client('rds-data')
# response = client.execute_statement(
#     secretArn = secretARN,
#     database = dbName,
#     resourceArn = resourceARN,
#     sql = 'Show Tables'
# )
# display(response['records'])

# %%
# # Helper method to execute a SQL query
# def execute(q):
#     response = client.execute_statement(
#         secretArn = secretARN,
#         database = dbName,
#         resourceArn = resourceARN,
#         sql = q
#     )
#     return response

# # Execute longer queries for select statements (need to go possibly to > 1MB)
# def executeBatch(q):
#     responses = []
#     qTemp = ''' Select Count(*) from QAResults '''
#     numEntries = execute(qTemp)['records'][0][0]['longValue']
#     limit = 1000
#     #print('numEntries:', numEntries)
#     for i in range(numEntries//limit + 1):
#         response = client.execute_statement(
#             secretArn = secretARN,
#             database = dbName,
#             resourceArn = resourceARN,
#             sql = q + ' Limit {} Offset {}'.format(limit, i * limit)
#         )
#         #print(response)
#         responses.append(response['records'])
#     return responses

# #deleteTable()

# %%
# # Create the basic table
# def createTable():
#     q = '''
#         Create table if not exists QAResults(
#             SerialNumber VARCHAR(30),
#             BatchNumber VARCHAR(30),
#             Date VARCHAR(10),
#             Tester VARCHAR(30),
#             FunctionalTest VARCHAR(4),
#             LogMessage text,
#             primary key (SerialNumber)
#         )
#     '''
#     return execute(q)

# # Simple method to return date in YYYY-MM-DD format
# def getDate():
#     return dt.datetime.today().strftime('%Y-%m-%d') # YYYY-MM-DD

# # Fetch an entry based off of serial number
# def getEntry(sn):
#     try:
#         q = ''' SELECT * FROM QAResults where SerialNumber = '{}' '''.format(sn)
#         return execute(q)
#     except Exception as e:
#         print('Issue with get entry:', e)

# # Helper method to insert an entry
# # sn, bn, date, tester, ft, log
# def insertEntry(sn, bn, ft, tst, msg, date = getDate()):
#     try:
#         q = ''' Insert into QAResults values ('%s', '%s', '%s', '%s', '%s', '%s')''' % (sn, bn, date, tst, ft, msg)
#         return execute(q)
#     except Exception as e:
#         print('Issue with add entry:', e)

# # Delete an entry based on SN alone
# def deleteEntry(sn):
#     try:
#         q = ''' Delete from QAResults where SerialNumber = '%s' ''' % (sn)
#         return execute(q)
#     except Exception as e:
#         print('Issue with delete entry:', e)

# # Modify a field based off of SN
# def modifyEntry(sn, field, newVal):
#     try:
#         q = ''' Update QAResults set {} = '{}' where SerialNumber = '{}' '''.format(field, newVal,sn)
#         return execute(q)
#     except Exception as e:
#         print('Issue with edit entry:', e)

# # Get all the results for the table
# def displayAll():
#     try:
#         print('\n\nQAResults Table\n')
#         q = ''' Select * From QAResults '''
#         records = executeBatch(q)
#         entries = records[0]
#         for r in entries:
#             print('Entry:', r)
#     except Exception as e:
#         print('Issue with displaying table:', e)

# # Delete the entire table
# def deleteTable():
#     try:
#         q = 'Drop Table QAResults'
#         return execute(q)
#     except Exception as e:
#         print('Issue while deleting table:', e)

# %%
# # Initial Testing the framework above
# createTable()
# #displayAll() # After initial table creation
# insertEntry('EEE833134W0', 'E2', 'Pass', 'Zach', 'Everything works')
# insertEntry('EEE833134W1', 'E2', 'Fail', 'Ruohan','Everything works')
# insertEntry('EEE833134W2', 'E2','Fail', 'Ryan','Breakdown occurred')
# displayAll() # After insertion of entries
# modifyEntry('EEE833134W1', 'BatchNumber', 'F33')
# displayAll() # After modification of an entry
# deleteEntry('EEE833134W2')
# displayAll() # After deletion of an entry

# %%
# # Functions + Variables to mass insert entries (consistently) into the database
# snPrefix = ['EUHWQ3931-', 'ABC22', 'RRH43144', '283367144']
# batchNums = ['EE1', 'FF2', 'GG3']
# testers = ['Zach', 'Ryan', 'Ruohan', 'Nikki', 'Megan']
# results = ['Pass', 'Fail']
# dates = [getDate(), '2020-05-02', '2020-06-09', '2019-11-27', '2021-04-19', '2021-04-01']
# messages = ['Camera issue', 'Night mode issue', 'Other issue-unlisted']
# passMsg = 'Everything works'

# def massInsertEntry(n):
#     for i in range(n):
#         sn = snPrefix[i % 4] + str(i)
#         bn = batchNums[i % 3]
#         t = testers[i % 5]
#         res = results[int(i % 4 == 0)]
#         d = dates[i % 6]
#         msg = passMsg if res == 'Pass' else messages[i % 3]
#         insertEntry(sn, bn, res, t, msg, d)
# massInsertEntry(50)
# displayAll()
